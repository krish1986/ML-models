# %%
! git clone https://github.com/laxmimerit/twitter-data.git
# Out:
# Cloning into 'twitter-data'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Activation, Dropout, Conv1D, GlobalMaxPooling1D, MaxPooling1D
import numpy as np
import pandas as pd
from numpy import array
from sklearn.model_selection import train_test_split
import itertools

# %%
df = pd.read_csv('/content/twitter-data/twitter4000.csv')

# %%
df.head()
# Out:
#                                               twitts  sentiment
# 0  is bored and wants to watch a movie  any sugge...          0
# 1           back in miami.  waiting to unboard ship           0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                  ughhh i am so tired  blahhhhhhhhh          0
# 4  @mandagoforth me bad! It's funny though. Zacha...          0

# %%
df['sentiment'].value_counts()
# Out:
# 1    2000
# 0    2000
# Name: sentiment, dtype: int64

# %%
text = df['twitts'].tolist()
text[:10]
# Out:
# ['is bored and wants to watch a movie  any suggestions?',
#  'back in miami.  waiting to unboard ship ',
#  "@misskpey awwww dnt dis brng bak memoriessss,  I thnk I'm sad. LoL",
#  'ughhh i am so tired  blahhhhhhhhh',
#  "@mandagoforth me bad! It's funny though. Zachary Quinto is only there for a few though.  &amp; to reply just put the @ symbol before the name!",
#  "brr, i'm so cold. at the moment doing my assignment on Huntington's Disease, which is really depressing ",
#  "@kevinmarquis haha yep but i really need to sleep, i feel like crap lol cant sleep when he's away  god i'm pathetic!",
#  "eating some ice-cream while I try to see @peterfacinelli's followers numbre raise...not working sadly ",
#  '@phatty84 just hella bored at work  lol',
#  'Food poisoning blowssss ']

# %%
y = df['sentiment']

# %% [markdown]
# Now we will use the class Tokenizer() to convert the data from text to numbers. This class allows to vectorize a text corpus, by turning each text into either a sequence of integers (each integer being the index of a token in a dictionary) or into a vector where the coefficient for each token could be binary, based on word count, based on tf-idf.

# %%
token  = Tokenizer()
token.fit_on_texts(text)
token

# %% [markdown]
# word_indexis index -> word dictionary so every word gets a unique integer value. It starts from 0 so we will add 1 to get the vocab_size. vocab_size is the total number of unique words in our dataset.

# %%
vocab = token.index_word
vocab
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'the',
#  4: 'a',
#  5: 'my',
#  6: 'and',
#  7: 'you',
#  8: 'is',
#  9: 'it',
#  10: 'in',
#  11: 'for',
#  12: 'of',
#  13: 'me',
#  14: 'on',
#  15: 'so',
#  16: 'that',
#  17: "i'm",
#  18: 'have',
#  19: 'at',
#  20: 'but',
#  21: 'just',
#  22: 'was',
#  23: 'with',
#  24: 'not',
#  25: 'be',
#  26: 'this',
#  27: 'day',
#  28: 'up',
#  29: 'now',
#  30: 'good',
#  31: 'all',
#  32: 'get',
#  33: 'out',
#  34: 'go',
#  35: 'no',
#  36: 'http',
#  37: 'today',
#  38: 'like',
#  39: 'are',
#  40: 'love',
#  41: 'your',
#  42: 'quot',
#  43: 'too',
#  44: 'lol',
#  45: 'work',
#  46: 'got',
#  47: "it's",
#  48: 'amp',
#  49: 'do',
#  50: 'com',
#  51: 'u',
#  52: 'back',
#  53: 'going',
#  54: 'what',
#  55: 'time',
#  56: 'from',
#  57: 'had',
#  58: 'will',
#  59: 'know',
#  60: 'about',
#  61: 'im',
#  62: 'am',
#  63: "don't",
#  64: 'can',
#  65: 'one',
#  66: 'really',
#  67: "can't",
#  68: 'we',
#  69: 'oh',
#  70: 'well',
#  71: 'still',
#  72: '2',
#  73: 'some',
#  74: 'its',
#  75: 'miss',
#  76: 'want',
#  77: 'see',
#  78: 'when',
#  79: 'home',
#  80: 'think',
#  81: 'an',
#  82: 'as',
#  83: 'if',
#  84: 'night',
#  85: 'need',
#  86: 'again',
#  87: 'new',
#  88: 'there',
#  89: 'morning',
#  90: 'here',
#  91: 'how',
#  92: 'her',
#  93: 'much',
#  94: 'thanks',
#  95: 'or',
#  96: 'they',
#  97: '3',
#  98: 'last',
#  99: 'off',
#  100: 'more',
#  101: 'only',
#  102: 'been',
#  103: 'has',
#  104: 'great',
#  105: 'tomorrow',
#  106: 'sorry',
#  107: 'why',
#  108: 'sleep',
#  109: 'twitter',
#  110: 'haha',
#  111: 'then',
#  112: 'nice',
#  113: 'bad',
#  114: 'twitpic',
#  115: 'sad',
#  116: 'way',
#  117: 'feel',
#  118: 'hope',
#  119: 'come',
#  120: 'fun',
#  121: 'wish',
#  122: 'gonna',
#  123: 'by',
#  124: 'tonight',
#  125: 'he',
#  126: 'happy',
#  127: 'yeah',
#  128: 'should',
#  129: "that's",
#  130: 'very',
#  131: 'over',
#  132: 'she',
#  133: 'better',
#  134: 'watching',
#  135: 'wait',
#  136: 'though',
#  137: 'dont',
#  138: 'make',
#  139: 'did',
#  140: 'would',
#  141: 'hate',
#  142: 'even',
#  143: "didn't",
#  144: 'getting',
#  145: "i've",
#  146: 'bit',
#  147: 'lt',
#  148: 'long',
#  149: 'thank',
#  150: 'right',
#  151: 'after',
#  152: 'week',
#  153: 'days',
#  154: "you're",
#  155: 'please',
#  156: 'people',
#  157: 'him',
#  158: 'show',
#  159: 'down',
#  160: 'were',
#  161: "i'll",
#  162: 'done',
#  163: 'look',
#  164: 'doing',
#  165: 'hey',
#  166: 'take',
#  167: 'never',
#  168: 'wanna',
#  169: 'little',
#  170: 'yes',
#  171: 'x',
#  172: 'awesome',
#  173: 'our',
#  174: 'who',
#  175: 'bed',
#  176: 'next',
#  177: 'hours',
#  178: 'them',
#  179: 'school',
#  180: 'friends',
#  181: 'cool',
#  182: 'cant',
#  183: 'could',
#  184: 'soon',
#  185: 'always',
#  186: 'us',
#  187: 'working',
#  188: 'life',
#  189: 'something',
#  190: 'pretty',
#  191: 'watch',
#  192: 'tired',
#  193: 'best',
#  194: 'someone',
#  195: "won't",
#  196: 'girl',
#  197: '4',
#  198: 'ok',
#  199: 'already',
#  200: 'hot',
#  201: 'sick',
#  202: 'thing',
#  203: 'maybe',
#  204: 'first',
#  205: 'weekend',
#  206: 'waiting',
#  207: 'away',
#  208: 'man',
#  209: 'help',
#  210: 'looking',
#  211: 'being',
#  212: '1',
#  213: 'game',
#  214: 'old',
#  215: 'let',
#  216: 'feeling',
#  217: 'early',
#  218: 'before',
#  219: 'find',
#  220: 'sun',
#  221: 'such',
#  222: 'guess',
#  223: 'other',
#  224: 'another',
#  225: 'hear',
#  226: 'trying',
#  227: 'least',
#  228: 'his',
#  229: 'sounds',
#  230: 'thought',
#  231: 'summer',
#  232: 'ur',
#  233: 'yay',
#  234: 'same',
#  235: 'sure',
#  236: 'movie',
#  237: 'because',
#  238: 'tweet',
#  239: 'guys',
#  240: 'house',
#  241: 'having',
#  242: 'everyone',
#  243: 'friend',
#  244: 'omg',
#  245: 'made',
#  246: 'ly',
#  247: 'phone',
#  248: 'say',
#  249: 'yesterday',
#  250: 'follow',
#  251: 'ya',
#  252: 'car',
#  253: 'might',
#  254: 'any',
#  255: 'lost',
#  256: 'actually',
#  257: 'than',
#  258: "doesn't",
#  259: 'ugh',
#  260: 'n',
#  261: 'also',
#  262: 'where',
#  263: 'left',
#  264: 'w',
#  265: 'keep',
#  266: 'p',
#  267: 'damn',
#  268: 'myself',
#  269: 'two',
#  270: 'family',
#  271: 'hair',
#  272: 'check',
#  273: 'stop',
#  274: 'gotta',
#  275: 'cute',
#  276: 'may',
#  277: 'put',
#  278: 'many',
#  279: 'hard',
#  280: 'start',
#  281: 'ever',
#  282: 'excited',
#  283: 'd',
#  284: 'makes',
#  285: 'few',
#  286: 'yet',
#  287: 'missed',
#  288: 'ready',
#  289: 'far',
#  290: 'into',
#  291: 'stuff',
#  292: 'later',
#  293: 'head',
#  294: 'glad',
#  295: 'while',
#  296: 'read',
#  297: 'party',
#  298: 'lovely',
#  299: 'went',
#  300: 'song',
#  301: 'listening',
#  302: 'office',
#  303: 'finally',
#  304: 'bored',
#  305: 'god',
#  306: 'until',
#  307: 'saw',
#  308: 'nothing',
#  309: 'things',
#  310: 'rain',
#  311: 'wow',
#  312: 'aww',
#  313: 'kind',
#  314: 'live',
#  315: 'cold',
#  316: 'try',
#  317: 'looks',
#  318: 'coming',
#  319: 'tell',
#  320: 'found',
#  321: 'weather',
#  322: 'sunday',
#  323: 'once',
#  324: 'thats',
#  325: 'win',
#  326: 'friday',
#  327: 'beautiful',
#  328: 'funny',
#  329: 'tho',
#  330: 'hell',
#  331: 'hi',
#  332: 'sweet',
#  333: 'baby',
#  334: "i'd",
#  335: 'play',
#  336: 'iphone',
#  337: 'luck',
#  338: 'b',
#  339: 't',
#  340: 'enough',
#  341: 'till',
#  342: 'eat',
#  343: 'music',
#  344: 'real',
#  345: 'wants',
#  346: "he's",
#  347: 'said',
#  348: 'fuck',
#  349: '10',
#  350: 'times',
#  351: 'does',
#  352: "isn't",
#  353: 'totally',
#  354: '5',
#  355: 'stay',
#  356: 'monday',
#  357: 'tv',
#  358: 'taking',
#  359: 'forgot',
#  360: 'hurts',
#  361: 'outside',
#  362: "haven't",
#  363: 'okay',
#  364: 'world',
#  365: 'amazing',
#  366: 'yep',
#  367: 'followers',
#  368: 'guy',
#  369: 'sucks',
#  370: 'following',
#  371: 'shopping',
#  372: 'those',
#  373: 'thinking',
#  374: 'leave',
#  375: 'must',
#  376: 'almost',
#  377: 'anything',
#  378: 'believe',
#  379: 'enjoy',
#  380: 'crazy',
#  381: 'hurt',
#  382: 'either',
#  383: 'sooo',
#  384: 'call',
#  385: 'www',
#  386: 'which',
#  387: '6',
#  388: 'cause',
#  389: 'whole',
#  390: 'shit',
#  391: 'heard',
#  392: 'gone',
#  393: 'wrong',
#  394: 'year',
#  395: 'job',
#  396: 'used',
#  397: 'mean',
#  398: 'hit',
#  399: 'o',
#  400: 'anymore',
#  401: 'most',
#  402: 'lot',
#  403: 'heart',
#  404: 'tinyurl',
#  405: 'give',
#  406: 'lunch',
#  407: 'pool',
#  408: 'birthday',
#  409: 'food',
#  410: 'cuz',
#  411: 'woke',
#  412: "she's",
#  413: 'hahaha',
#  414: 'both',
#  415: 'run',
#  416: 'place',
#  417: 'awww',
#  418: 'big',
#  419: 'forward',
#  420: 's',
#  421: 'use',
#  422: "we're",
#  423: 'asleep',
#  424: 'beach',
#  425: 'anyone',
#  426: 'r',
#  427: 'talk',
#  428: 'seen',
#  429: 'didnt',
#  430: 'moving',
#  431: 'took',
#  432: '8',
#  433: 'change',
#  434: "wasn't",
#  435: 'ill',
#  436: 'm',
#  437: 'without',
#  438: 'sunny',
#  439: 'boring',
#  440: 'late',
#  441: 'trip',
#  442: 'stupid',
#  443: 'playing',
#  444: 'welcome',
#  445: 'btw',
#  446: 'else',
#  447: 'gt',
#  448: 'reply',
#  449: 'name',
#  450: 'eating',
#  451: "what's",
#  452: 'train',
#  453: 'looked',
#  454: 'fail',
#  455: 'site',
#  456: 'jealous',
#  457: 'came',
#  458: 'picture',
#  459: 'buy',
#  460: 'full',
#  461: 'through',
#  462: 'tweets',
#  463: 'these',
#  464: 'side',
#  465: 'busy',
#  466: 'sometimes',
#  467: 'says',
#  468: 'news',
#  469: 'google',
#  470: 'poor',
#  471: 'every',
#  472: 'free',
#  473: "couldn't",
#  474: 'lots',
#  475: 'using',
#  476: 'idea',
#  477: 'ago',
#  478: 'saturday',
#  479: 'person',
#  480: 'final',
#  481: 'told',
#  482: 'lmao',
#  483: 'end',
#  484: 'nite',
#  485: 'tour',
#  486: 'aw',
#  487: 'pain',
#  488: 'bring',
#  489: 'open',
#  490: 'soo',
#  491: 'homework',
#  492: 'anyway',
#  493: 'facebook',
#  494: 'finished',
#  495: 'blue',
#  496: 'mine',
#  497: 'walk',
#  498: 'raining',
#  499: 'exam',
#  500: 'stuck',
#  501: 'mom',
#  502: 'own',
#  503: 'breakfast',
#  504: 'class',
#  505: 'rest',
#  506: "let's",
#  507: 'kinda',
#  508: 'since',
#  509: 'seriously',
#  510: 'able',
#  511: 'leaving',
#  512: 'ha',
#  513: '30',
#  514: 'l',
#  515: 'hehe',
#  516: 'talking',
#  517: 'blog',
#  518: 'computer',
#  519: 'wanted',
#  520: 'goes',
#  521: 'y',
#  522: 'cannot',
#  523: '12',
#  524: 'room',
#  525: 'headache',
#  526: 'xx',
#  527: 'sister',
#  528: 'definitely',
#  529: 'c',
#  530: 'soooo',
#  531: 'post',
#  532: 'movies',
#  533: 'video',
#  534: 'coffee',
#  535: 'pay',
#  536: 'crap',
#  537: 'ice',
#  538: 'tried',
#  539: 'tommcfly',
#  540: 'internet',
#  541: 'their',
#  542: 'agree',
#  543: 'wake',
#  544: "there's",
#  545: 'send',
#  546: 'hello',
#  547: 'break',
#  548: 'hour',
#  549: 'fm',
#  550: 'needed',
#  551: 'afternoon',
#  552: 'top',
#  553: 'test',
#  554: 'everything',
#  555: 'missing',
#  556: 'true',
#  557: 'meet',
#  558: 'broke',
#  559: 'david',
#  560: 'pic',
#  561: 'dog',
#  562: 'lucky',
#  563: 'plurk',
#  564: 'face',
#  565: 'half',
#  566: 'enjoying',
#  567: 'dad',
#  568: 'church',
#  569: 'cream',
#  570: 'loving',
#  571: 'wont',
#  572: 'town',
#  573: 'dinner',
#  574: 'alone',
#  575: 'loved',
#  576: "they're",
#  577: 'sore',
#  578: 'years',
#  579: 'making',
#  580: 'probably',
#  581: 'die',
#  582: 'set',
#  583: 'heading',
#  584: 'eye',
#  585: 'money',
#  586: 'blip',
#  587: 'instead',
#  588: 'concert',
#  589: 'sat',
#  590: 'shower',
#  591: 'started',
#  592: 'hopefully',
#  593: 'july',
#  594: 'lil',
#  595: 'perfect',
#  596: 'under',
#  597: 'fam',
#  598: 'yea',
#  599: 'reading',
#  600: 'gave',
#  601: 'sleepy',
#  602: 'awake',
#  603: 'works',
#  604: 'feels',
#  605: 'interesting',
#  606: 'online',
#  607: 'turn',
#  608: 'xd',
#  609: 'sent',
#  610: 'happened',
#  611: 'boo',
#  612: 'seem',
#  613: 'goodnight',
#  614: 'red',
#  615: 'parents',
#  616: 'nose',
#  617: 'brothers',
#  618: 'quite',
#  619: 'heat',
#  620: 'whats',
#  621: 'wonderful',
#  622: 'chat',
#  623: 'ppl',
#  624: 'around',
#  625: 'jonas',
#  626: '20',
#  627: 'order',
#  628: 'e',
#  629: 'month',
#  630: 'needs',
#  631: 'three',
#  632: 'dreams',
#  633: 'dude',
#  634: 'link',
#  635: 'happen',
#  636: 'kids',
#  637: 'bought',
#  638: 'blood',
#  639: 'pick',
#  640: '7',
#  641: 'text',
#  642: 'flight',
#  643: 'sound',
#  644: 'couple',
#  645: 'together',
#  646: 'care',
#  647: 'catch',
#  648: 'means',
#  649: 'beer',
#  650: 'goin',
#  651: 'mind',
#  652: 'fantastic',
#  653: 'cake',
#  654: 'liked',
#  655: 'lets',
#  656: 'ive',
#  657: 'favorite',
#  658: 'yup',
#  659: 'via',
#  660: 'worth',
#  661: 'garden',
#  662: 'team',
#  663: 'move',
#  664: 'park',
#  665: 'june',
#  666: 'shall',
#  667: "you'll",
#  668: 'dnt',
#  669: '0',
#  670: 'wonder',
#  671: 'moon',
#  672: 'girls',
#  673: 'annoying',
#  674: 'sit',
#  675: 'feet',
#  676: 'wondering',
#  677: 'air',
#  678: 'throat',
#  679: 'season',
#  680: 'photo',
#  681: 'broken',
#  682: 'power',
#  683: 'wtf',
#  684: 'view',
#  685: 'myspace',
#  686: 'understand',
#  687: 'happens',
#  688: 'la',
#  689: 'unfortunately',
#  690: 'bus',
#  691: 'mum',
#  692: 'english',
#  693: 'interview',
#  694: 'gets',
#  695: 'water',
#  696: 'watched',
#  697: 'dream',
#  698: 'sitting',
#  699: 'save',
#  700: 'tweeting',
#  701: '2nd',
#  702: 'voice',
#  703: 'weeks',
#  704: 'king',
#  705: 'mr',
#  706: 'problem',
#  707: 'ooh',
#  708: 'fact',
#  709: 'driving',
#  710: 'random',
#  711: 'bday',
#  712: 'putting',
#  713: 'loves',
#  714: 'forever',
#  715: 'sigh',
#  716: 'seeing',
#  717: 'mad',
#  718: 'congrats',
#  719: '15',
#  720: 'starting',
#  721: 'upset',
#  722: 'studying',
#  723: 'ah',
#  724: 'fell',
#  725: 'nope',
#  726: 'apparently',
#  727: 'walking',
#  728: 'drink',
#  729: 'knew',
#  730: 'boy',
#  731: 'months',
#  732: 'wedding',
#  733: '2day',
#  734: 'date',
#  735: 'cat',
#  736: 'laptop',
#  737: 'chocolate',
#  738: 'huge',
#  739: 'story',
#  740: 'keeps',
#  741: "we'll",
#  742: 'message',
#  743: 'wishes',
#  744: 'longer',
#  745: 'update',
#  746: 'radio',
#  747: 'fast',
#  748: 'rainy',
#  749: 'storm',
#  750: 'boys',
#  751: 'saying',
#  752: 'mileycyrus',
#  753: 'tickets',
#  754: 'gosh',
#  755: 'won',
#  756: "you've",
#  757: 'bout',
#  758: 'plan',
#  759: 'hug',
#  760: 'super',
#  761: 'mall',
#  762: 'close',
#  763: 'puppy',
#  764: 'ipod',
#  765: 'slept',
#  766: 'hoping',
#  767: 'hand',
#  768: 'ass',
#  769: 'fucking',
#  770: 'study',
#  771: 'pass',
#  772: 'dang',
#  773: 'awards',
#  774: 'nap',
#  775: 'airport',
#  776: '100',
#  777: 'etc',
#  778: 'dance',
#  779: 'shes',
#  780: 'credit',
#  781: 'ouch',
#  782: 'relaxing',
#  783: 'vacation',
#  784: 'club',
#  785: 'proud',
#  786: 'smile',
#  787: 'pics',
#  788: 'idk',
#  789: 'stopped',
#  790: 'race',
#  791: 'visit',
#  792: 'wishing',
#  793: 'comes',
#  794: 'answer',
#  795: 'ball',
#  796: 'london',
#  797: 'number',
#  798: 'space',
#  799: 'band',
#  800: 'mac',
#  801: 'spending',
#  802: 'short',
#  803: 'city',
#  804: 'whoever',
#  805: 'â\x99«',
#  806: 'em',
#  807: 'part',
#  808: 'ahhh',
#  809: '11',
#  810: 'foot',
#  811: 'write',
#  812: '1st',
#  813: 'mtv',
#  814: 'black',
#  815: 'figure',
#  816: 'bet',
#  817: 'spend',
#  818: 'tea',
#  819: 'bar',
#  820: 'thx',
#  821: 'green',
#  822: 'sunshine',
#  823: 'babe',
#  824: 'silly',
#  825: 'slow',
#  826: 'argh',
#  827: 'finish',
#  828: 'ate',
#  829: "who's",
#  830: 'add',
#  831: 'box',
#  832: 'store',
#  833: 'eyes',
#  834: '9',
#  835: 'worry',
#  836: 'calling',
#  837: 'stomach',
#  838: 'less',
#  839: 'yours',
#  840: 'couch',
#  841: 'laundry',
#  842: 'drinking',
#  843: 'six',
#  844: 'running',
#  845: 'til',
#  846: 'jk',
#  847: 'strawberry',
#  848: 'shut',
#  849: 'lame',
#  850: 'share',
#  851: 'inside',
#  852: 'sunburn',
#  853: 'album',
#  854: 'fix',
#  855: 'worst',
#  856: 'fml',
#  857: 'chris',
#  858: 'headed',
#  859: 'present',
#  860: 'bitch',
#  861: 'giving',
#  862: 'folks',
#  863: 'low',
#  864: 'killed',
#  865: 'k',
#  866: 'prob',
#  867: 'evening',
#  868: 'fan',
#  869: 'account',
#  870: 'xxx',
#  871: 'na',
#  872: 'screen',
#  873: 'chicken',
#  874: 'minutes',
#  875: 'especially',
#  876: 'laugh',
#  877: 'note',
#  878: 'pink',
#  879: 'laying',
#  880: 'mix',
#  881: 'join',
#  882: 'high',
#  883: 'writing',
#  884: 'g',
#  885: 'holiday',
#  886: 'mail',
#  887: 'alot',
#  888: 'whatever',
#  889: 'packing',
#  890: 'followfriday',
#  891: 'twit',
#  892: 'moment',
#  893: 'sadly',
#  894: 'fall',
#  895: 'state',
#  896: 'tuesday',
#  897: 'grocery',
#  898: 'dm',
#  899: 'outta',
#  900: 'brother',
#  901: 'thursday',
#  902: 'sky',
#  903: 'pack',
#  904: 'lazy',
#  905: 'nails',
#  906: 'afraid',
#  907: 'chance',
#  908: 'nyc',
#  909: 'roll',
#  910: 'flu',
#  911: 'coz',
#  912: 'gettin',
#  913: 'pm',
#  914: 'lady',
#  915: 'tummy',
#  916: 'fight',
#  917: 'shirt',
#  918: 'v',
#  919: 'cancelled',
#  920: 'threw',
#  921: 'cut',
#  922: 'waking',
#  923: 'woo',
#  924: 'ohhh',
#  925: 'exams',
#  926: 'line',
#  927: 'tumblr',
#  928: 'catching',
#  929: 'question',
#  930: 'weekends',
#  931: 'pants',
#  932: 'xo',
#  933: "today's",
#  934: 'donniewahlberg',
#  935: "aren't",
#  936: 'supposed',
#  937: 'scared',
#  938: 'learn',
#  939: 'others',
#  940: 'body',
#  941: 'indeed',
#  942: 'wearing',
#  943: 'hospital',
#  944: 'official',
#  945: 'sob',
#  946: 'worse',
#  947: 'sis',
#  948: 'decided',
#  949: 'gah',
#  950: 'lose',
#  951: 'shame',
#  952: 'wife',
#  953: 'bright',
#  954: 'camera',
#  955: 'charger',
#  956: 'remember',
#  957: 'singing',
#  958: 'session',
#  959: 'miley',
#  960: 'boyfriend',
#  961: 'cup',
#  962: 'noticed',
#  963: 'shot',
#  964: 'total',
#  965: 'safe',
#  966: 'although',
#  967: 'neither',
#  968: 'calls',
#  969: 'freaking',
#  970: 'ahh',
#  971: 'alright',
#  972: 'mothers',
#  973: 'planning',
#  974: 'miles',
#  975: 'teacher',
#  976: 'hilarious',
#  977: 'word',
#  978: 'lonely',
#  979: 'picking',
#  980: 'suck',
#  981: 'sexy',
#  982: 'wednesday',
#  983: 'demi',
#  984: 'ms',
#  985: 'shoes',
#  986: 'straight',
#  987: 'nick',
#  988: 'grrr',
#  989: 'dougiemcfly',
#  990: 'myloc',
#  991: 'mother',
#  992: 'bff',
#  993: 'played',
#  994: 'dress',
#  995: 'husband',
#  996: 'code',
#  997: 'suit',
#  998: 'case',
#  999: 'book',
#  1000: 'luv',
#  ...}

# %%
vocab_size = len(token.word_index) + 1 # since the index starts from zero

# %%
vocab_size
# Out:
# 10135

# %%
x = ['i to the a and']

# %%
token.texts_to_sequences(x)
# Out:
# [[1, 2, 3, 4, 6]]

# %%
encoded_text = token.texts_to_sequences(text)

# %%
encoded_text
# Out:
# [[8, 304, 6, 345, 2, 191, 4, 236, 254, 3079],
#  [52, 10, 1019, 206, 2, 3080, 3081],
#  [3082, 1197, 668, 1955, 3083, 1956, 3084, 1, 3085, 17, 115, 44],
#  [1957, 1, 62, 15, 192, 3086],
#  [3087,
#   13,
#   113,
#   47,
#   328,
#   136,
#   3088,
#   3089,
#   8,
#   101,
#   88,
#   11,
#   4,
#   285,
#   136,
#   48,
#   2,
#   448,
#   21,
#   277,
#   3,
#   3090,
#   218,
#   3,
#   449],
#  [3091,
#   17,
#   15,
#   315,
#   19,
#   3,
#   892,
#   164,
#   5,
#   1459,
#   14,
#   3092,
#   3093,
#   386,
#   8,
#   66,
#   1460],
#  [3094,
#   110,
#   366,
#   20,
#   1,
#   66,
#   85,
#   2,
#   108,
#   1,
#   117,
#   38,
#   536,
#   44,
#   182,
#   108,
#   78,
#   346,
#   207,
#   305,
#   17,
#   3095],
#  [450, 73, 537, 569, 295, 1, 316, 2, 77, 3096, 367, 3097, 1461, 24, 187, 893],
#  [3098, 21, 1958, 304, 19, 45, 44],
#  [409, 3099, 3100],
#  [3101, 132, 609, 79, 3, 193, 368, 17, 131, 3, 158, 199],
#  [3102, 127, 1, 139, 226, 2, 1020, 9, 29, 1, 222, 74, 55, 2, 3103, 16, 3104],
#  [67, 894, 423],
#  [1959,
#   119,
#   52,
#   56,
#   211,
#   159,
#   387,
#   669,
#   48,
#   68,
#   255,
#   1462,
#   3,
#   3105,
#   71,
#   570,
#   5,
#   1959,
#   329],
#  [1960, 3106, 3107, 46, 3108, 3109],
#  [3110, 1463, 70, 19, 227, 17, 28, 2],
#  [3111,
#   1,
#   245,
#   212,
#   1961,
#   51,
#   72,
#   36,
#   146,
#   246,
#   3112,
#   1,
#   538,
#   20,
#   74,
#   507,
#   1962,
#   410,
#   1,
#   1198,
#   219,
#   787],
#  [3113,
#   69,
#   1,
#   1021,
#   5,
#   3114,
#   33,
#   2,
#   1199,
#   451,
#   263,
#   12,
#   9,
#   388,
#   1,
#   143,
#   76,
#   2,
#   316,
#   1464,
#   73,
#   159,
#   1465],
#  [3115,
#   3116,
#   31,
#   12,
#   39,
#   3117,
#   9,
#   20,
#   96,
#   39,
#   24,
#   1466,
#   3118,
#   1200,
#   386,
#   507,
#   369,
#   15,
#   68,
#   571,
#   32,
#   2,
#   1022,
#   2,
#   51],
#  [3119,
#   165,
#   88,
#   35,
#   64,
#   49,
#   1963,
#   6,
#   24,
#   52,
#   10,
#   572,
#   306,
#   1467,
#   176,
#   152,
#   75,
#   7],
#  [3120,
#   15,
#   788,
#   78,
#   9,
#   610,
#   95,
#   91,
#   20,
#   1,
#   3121,
#   789,
#   370,
#   7,
#   91,
#   39,
#   7,
#   91,
#   18,
#   7,
#   102],
#  [54, 8, 28, 23, 5, 3122],
#  [52,
#   3123,
#   86,
#   37,
#   611,
#   15,
#   473,
#   452,
#   82,
#   1201,
#   101,
#   719,
#   153,
#   1468,
#   790,
#   11,
#   188,
#   3124],
#  [3125, 69, 1, 670, 83, 3, 1964, 14, 3, 1469, 8, 720, 2, 34],
#  [3126, 7, 347, 42, 3127, 11, 573, 42, 1, 22, 1965, 1966],
#  [3128, 87, 671, 8, 101, 3129, 153, 207, 256, 16, 8, 1023],
#  [1470, 3, 3130, 38, 35, 223],
#  [539, 1, 18, 4, 389, 10, 5, 1967, 43],
#  [1, 612, 2, 18, 255, 5, 1024, 1471],
#  [52,
#   56,
#   3,
#   424,
#   3131,
#   102,
#   4,
#   148,
#   55,
#   508,
#   1,
#   98,
#   57,
#   3132,
#   3133,
#   3134,
#   3135,
#   227,
#   3136,
#   8,
#   14,
#   92,
#   116,
#   2,
#   791,
#   13],
#  [3137, 613, 109, 1472, 99, 10, 81, 721, 895],
#  [390, 7, 1968, 3138, 69, 35, 7, 3139, 5, 3140],
#  [8, 792, 105, 58, 25, 1202, 257, 37, 20, 111, 793, 614, 27],
#  [1, 62, 15, 3141],
#  [1473, 1, 75, 157, 15, 93],
#  [1,
#   22,
#   3142,
#   28,
#   1474,
#   1969,
#   391,
#   31,
#   3,
#   3143,
#   453,
#   131,
#   6,
#   307,
#   474,
#   12,
#   1203],
#  [3144, 17, 24, 4, 1204],
#  [3145,
#   1970,
#   14,
#   896,
#   6,
#   1,
#   473,
#   25,
#   100,
#   3146,
#   1,
#   509,
#   59,
#   17,
#   1475,
#   454,
#   6,
#   1,
#   66,
#   63,
#   76,
#   2],
#  [722, 1025, 6, 897, 371, 31, 1971, 1476, 54, 4, 120, 27],
#  [540, 71, 159, 3147, 1, 64, 191, 3, 213, 106, 83, 7, 898, 1, 67, 794],
#  [723, 1477, 1, 64, 117, 3, 1972, 12, 372, 3148],
#  [304,
#   19,
#   45,
#   1,
#   63,
#   32,
#   899,
#   90,
#   1468,
#   1973,
#   3149,
#   3150,
#   124,
#   23,
#   5,
#   672,
#   1,
#   121,
#   3151,
#   22,
#   90],
#  [425, 76, 2, 77, 3152, 124, 1, 63, 76, 2, 34, 574, 43, 278, 3153],
#  [3154,
#   21,
#   453,
#   28,
#   3,
#   1974,
#   317,
#   328,
#   3155,
#   65,
#   1026,
#   3156,
#   9,
#   2,
#   3,
#   3157,
#   386,
#   1,
#   575,
#   3158,
#   329],
#  [71, 137, 32, 9],
#  [1, 66, 1478, 28, 26, 55, 1, 62, 4, 1975, 348, 5, 188],
#  [208,
#   1,
#   3159,
#   392,
#   11,
#   4,
#   3160,
#   54,
#   3,
#   330,
#   22,
#   1,
#   373,
#   318,
#   52,
#   79,
#   29,
#   17,
#   304],
#  [331, 3161, 91, 426, 51, 5, 332, 1, 75, 7],
#  [333, 319, 13, 174, 8, 132],
#  [3162,
#   24,
#   286,
#   144,
#   73,
#   209,
#   56,
#   5,
#   900,
#   48,
#   615,
#   26,
#   89,
#   576,
#   14,
#   541,
#   116,
#   131],
#  [3163, 451, 393, 139, 7, 76, 2, 427, 60, 9],
#  [1,
#   40,
#   5,
#   616,
#   3164,
#   20,
#   74,
#   66,
#   673,
#   13,
#   150,
#   29,
#   1,
#   140,
#   141,
#   2,
#   166,
#   9,
#   33],
#  [3165, 1027, 1, 22, 3166, 194, 6, 724],
#  [3167,
#   1479,
#   370,
#   1480,
#   320,
#   212,
#   1976,
#   3168,
#   27,
#   57,
#   1977,
#   72,
#   49,
#   264,
#   305,
#   1978,
#   475,
#   228,
#   449,
#   72,
#   32,
#   1979,
#   3169,
#   178,
#   59,
#   24,
#   54,
#   96,
#   49],
#  [1027, 3170, 127, 1, 76, 25, 510, 2, 306, 176, 394, 42],
#  [3171, 107],
#  [3172, 1, 45, 1980, 15, 725, 17, 52, 19, 45, 86, 37],
#  [3173, 3174, 1981, 455, 8, 71, 159],
#  [21, 411, 28, 1, 22, 53, 2, 34, 1028, 20, 17, 71, 577, 56, 901],
#  [3175, 1029, 54, 902, 154, 210, 19, 1030, 12, 1205, 48, 3176, 1982, 10, 3177],
#  [3178, 112, 1, 1206, 428, 16, 236, 286, 329],
#  [3179,
#   3180,
#   1481,
#   1031,
#   1482,
#   44,
#   6,
#   3181,
#   392,
#   788,
#   107,
#   125,
#   429,
#   49,
#   3182,
#   1,
#   137,
#   80,
#   44],
#  [3183,
#   170,
#   7,
#   1483,
#   9,
#   3184,
#   107,
#   229,
#   115,
#   6,
#   1,
#   18,
#   35,
#   476,
#   91,
#   214,
#   125,
#   22,
#   78,
#   125,
#   1032,
#   296,
#   9,
#   38,
#   349,
#   578,
#   477,
#   1983],
#  [3185, 3186, 106, 60, 3, 3187],
#  [3188, 1, 62, 456, 1, 40, 16, 208, 1, 287, 157, 98, 55, 125, 457, 2, 3189],
#  [1207, 5, 1033, 903, 412, 511, 2, 3190, 10, 478],
#  [3191, 413, 1, 542, 1, 1484, 38, 4, 333, 78, 96, 3192, 3, 617, 28, 512],
#  [3193, 20, 7, 167, 307, 3, 1984, 69, 3, 1984],
#  [3194,
#   334,
#   38,
#   2,
#   25,
#   904,
#   20,
#   96,
#   265,
#   14,
#   579,
#   13,
#   543,
#   28,
#   19,
#   3195,
#   20,
#   1,
#   49,
#   32,
#   269,
#   3196,
#   99,
#   4,
#   152,
#   15,
#   24,
#   618,
#   4,
#   395],
#  [3197, 34, 32, 409, 6, 111, 32, 288, 11, 45, 1208, 3198, 171],
#  [726, 1, 18, 1034, 14, 3199, 20, 308, 2, 335, 9, 23],
#  [3200,
#   155,
#   63,
#   215,
#   26,
#   368,
#   674,
#   176,
#   2,
#   13,
#   125,
#   46,
#   14,
#   331,
#   3201,
#   1985,
#   4,
#   3202,
#   148,
#   905,
#   6,
#   3203,
#   1035],
#  [1, 121, 1, 183, 25, 52, 10, 1209],
#  [3204, 266, 83, 101, 1, 22, 10, 1986, 1987],
#  [1,
#   46,
#   619,
#   3205,
#   14,
#   414,
#   675,
#   6,
#   62,
#   29,
#   3206,
#   12,
#   727,
#   267,
#   26,
#   321,
#   580,
#   3,
#   101,
#   479,
#   10,
#   3207,
#   373,
#   16],
#  [61,
#   52,
#   79,
#   10,
#   3208,
#   61,
#   3209,
#   192,
#   136,
#   6,
#   721,
#   1,
#   1036,
#   53,
#   2,
#   77,
#   3210,
#   19,
#   3,
#   3211,
#   795,
#   171],
#  [69, 6, 83, 101, 1988, 247, 429, 581, 1, 140, 59, 620, 53, 14, 19, 3, 1485],
#  [3212, 723, 1989, 1, 374, 11, 228, 14, 3213],
#  [103,
#   396,
#   100,
#   3214,
#   37,
#   257,
#   31,
#   3,
#   223,
#   350,
#   12,
#   3215,
#   3216,
#   1486,
#   1,
#   117,
#   1487],
#  [46, 35, 3217, 3218, 315, 79, 574, 6, 308, 2, 49],
#  [1210, 67, 219, 4, 3219, 1488, 1489, 90, 23, 3, 3220, 3221],
#  [3222, 1, 59, 54, 7, 397, 1, 117, 3223, 115, 43],
#  [1211,
#   165,
#   1490,
#   21,
#   676,
#   78,
#   351,
#   1491,
#   1990,
#   677,
#   86,
#   1,
#   140,
#   38,
#   2,
#   582,
#   5,
#   1991,
#   2,
#   3224,
#   9,
#   35,
#   336,
#   90],
#  [3225, 187, 14, 4, 322, 369, 63, 45, 43, 279],
#  [3226, 1, 307, 3, 3227, 3228, 6, 230, 3, 236, 10, 1992, 3229],
#  [53, 2, 796, 3230, 37, 122, 25, 15, 200],
#  [17,
#   1993,
#   2,
#   248,
#   16,
#   5,
#   3231,
#   1212,
#   207,
#   249,
#   10,
#   3,
#   89,
#   19,
#   97,
#   513,
#   1,
#   58,
#   75,
#   157,
#   15,
#   93,
#   1,
#   40,
#   7,
#   1994],
#  [105, 3, 98, 27, 12, 179, 278, 3232, 278, 3233, 278, 1995],
#  [3234, 5, 678, 8, 1996, 1, 76, 4, 728],
#  [3235,
#   17,
#   906,
#   1,
#   195,
#   18,
#   4,
#   907,
#   2,
#   17,
#   430,
#   52,
#   2,
#   1997,
#   14,
#   896,
#   231,
#   3236],
#  [458, 352, 1213, 14, 109, 1998],
#  [1999,
#   908,
#   17,
#   122,
#   222,
#   48,
#   248,
#   3,
#   480,
#   3237,
#   237,
#   194,
#   296,
#   3238,
#   323,
#   48,
#   3239,
#   1,
#   729,
#   174,
#   96,
#   160,
#   48,
#   481,
#   13,
#   22,
#   115],
#  [3240, 909, 1, 75, 5, 3241, 3242, 20, 1, 18, 16, 2000, 1492, 44],
#  [351, 1214, 18, 3, 3243, 3244, 797, 1, 21, 46, 398, 11, 5, 98, 238, 482],
#  [24, 216, 82, 104, 82, 1, 139, 3, 98, 55, 1, 1493, 2001, 297, 12, 65],
#  [83, 101, 96, 3245],
#  [1, 80, 17, 720, 2, 32, 201, 3246, 910],
#  [1, 63, 66, 32, 3, 389, 109, 202, 17, 3247],
#  [583, 2, 45, 36, 114, 50, 3248],
#  [3249, 36, 114, 50, 3250, 17, 15, 115, 26, 8, 15, 3251],
#  [431, 3, 730, 2002, 20, 35, 337, 15, 289],
#  [1,
#   670,
#   83,
#   544,
#   4,
#   42,
#   3252,
#   2003,
#   2004,
#   42,
#   1,
#   64,
#   545,
#   2,
#   5,
#   2005,
#   2006,
#   911,
#   125,
#   3253,
#   100,
#   55,
#   10,
#   3254,
#   257,
#   23,
#   13],
#  [61, 3255, 14, 2007, 1, 287, 9, 3256, 1215, 28],
#  [3257,
#   179,
#   8,
#   788,
#   179,
#   3258,
#   12,
#   1216,
#   264,
#   136,
#   2008,
#   51,
#   46,
#   232,
#   3259,
#   318,
#   28,
#   3260],
#  [546,
#   87,
#   3261,
#   61,
#   24,
#   216,
#   3,
#   193,
#   1,
#   18,
#   4,
#   2009,
#   1494,
#   3262,
#   375,
#   32,
#   133,
#   184],
#  [3263, 126, 3264, 106, 1, 167, 481, 7, 3265],
#  [164, 1217, 295, 134, 679, 387, 12, 270, 368, 128, 25, 33, 10, 3, 220],
#  [1, 185, 2010, 5, 271, 78, 9, 3266],
#  [54, 3, 330, 8, 53, 14, 8, 1495, 24, 318, 2, 1496, 29],
#  [3267,
#   3268,
#   1,
#   80,
#   72,
#   12,
#   5,
#   35,
#   30,
#   367,
#   263,
#   13,
#   3269,
#   69,
#   70,
#   44,
#   96,
#   128,
#   3270,
#   54,
#   2011,
#   912,
#   3271,
#   78,
#   96,
#   250,
#   13],
#  [3272,
#   11,
#   4,
#   1037,
#   1,
#   230,
#   16,
#   347,
#   42,
#   3273,
#   103,
#   81,
#   1497,
#   584,
#   1498,
#   42,
#   366,
#   17,
#   4,
#   798,
#   3274,
#   106,
#   11,
#   3,
#   332,
#   196],
#  [3275,
#   1,
#   21,
#   46,
#   4,
#   448,
#   56,
#   2012,
#   147,
#   97,
#   233,
#   19,
#   227,
#   74,
#   4,
#   799,
#   3276,
#   24,
#   1499,
#   4,
#   448,
#   56,
#   3,
#   239,
#   83,
#   1,
#   415,
#   290,
#   7,
#   1218,
#   800],
#  [8,
#   373,
#   60,
#   801,
#   2013,
#   10,
#   3,
#   1500,
#   220,
#   911,
#   46,
#   224,
#   298,
#   27,
#   71,
#   216,
#   4,
#   146],
#  [3277, 297, 54, 297, 1, 22, 187, 1468, 432, 913, 124],
#  [3278, 24, 162, 47, 376, 72, 62, 26, 3279, 133, 280, 1501, 3280],
#  [55, 2, 296, 2014, 1502],
#  [109, 195, 7, 2015, 13, 2, 433, 5, 680],
#  [324, 9, 1, 62, 53, 2, 166, 4, 547, 1, 46, 131, 2016, 3281],
#  [17,
#   206,
#   11,
#   5,
#   196,
#   2,
#   32,
#   3282,
#   82,
#   132,
#   3283,
#   2,
#   1503,
#   2017,
#   6,
#   1,
#   195,
#   77,
#   92,
#   11,
#   72,
#   731],
#  [1, 71, 46, 15, 278, 3284, 309, 16, 1, 168, 248, 2, 7],
#  [3285, 1, 2018, 2019, 1219, 77, 7, 3286, 514],
#  [1504, 1, 121, 2020, 2021, 140, 250, 13, 14, 3287],
#  [3288, 1, 75, 3289, 28, 10, 120, 3290, 3291, 1, 59, 9, 8, 1220],
#  [3292,
#   366,
#   23,
#   5,
#   269,
#   193,
#   180,
#   2022,
#   3293,
#   48,
#   3294,
#   20,
#   29,
#   47,
#   131,
#   22,
#   172,
#   515],
#  [348, 99, 2023, 681, 3295, 11, 3, 582],
#  [3296, 3297, 376, 1221, 61, 81, 214, 914],
#  [473, 32, 430, 26, 89, 187, 10, 3, 220, 1038, 8, 144, 2, 13],
#  [353, 3298, 19, 3, 1039, 12, 221, 4, 30, 1222],
#  [17, 66, 2024, 29],
#  [539, 107, 49, 7, 24, 1040, 13],
#  [915, 3299, 611, 26, 369],
#  [3300, 3301, 2025, 1, 434, 88, 2026],
#  [3302,
#   1505,
#   679,
#   1506,
#   802,
#   3303,
#   5,
#   3304,
#   682,
#   159,
#   3305,
#   290,
#   2027,
#   3306,
#   3307,
#   281,
#   3308,
#   145,
#   281,
#   2028],
#  [159,
#   79,
#   1223,
#   69,
#   2029,
#   1,
#   18,
#   2,
#   34,
#   2,
#   4,
#   732,
#   48,
#   58,
#   75,
#   33,
#   14,
#   3,
#   621,
#   3309],
#  [3310, 61, 15, 3311, 128, 12, 102, 2030, 6, 3312, 2031],
#  [3313,
#   110,
#   127,
#   733,
#   22,
#   72,
#   338,
#   483,
#   399,
#   394,
#   120,
#   27,
#   3314,
#   3315,
#   3316,
#   213,
#   3317,
#   3318,
#   2032,
#   354,
#   3319,
#   3320,
#   916,
#   20,
#   9,
#   2033],
#  [1, 121, 1, 71, 57, 585, 15, 1, 183, 459, 81, 2034, 803, 339, 917],
#  [3321,
#   54,
#   4,
#   27,
#   9,
#   22,
#   97,
#   548,
#   180,
#   1041,
#   2035,
#   3322,
#   371,
#   29,
#   79,
#   1,
#   141,
#   3323],
#  [2036, 139, 2, 804, 22, 263, 80, 2037, 263, 1224, 23, 7, 6, 3324, 218, 16],
#  [3325,
#   47,
#   15,
#   1507,
#   63,
#   618,
#   59,
#   54,
#   9,
#   8,
#   1,
#   22,
#   99,
#   249,
#   122,
#   18,
#   2,
#   3326,
#   9,
#   37],
#  [3327, 435, 265, 7, 28, 1, 18, 2, 355, 28, 11, 1225, 86, 1226],
#  [3328, 74, 24, 88, 400],
#  [345, 2, 34, 2, 3, 3329, 37, 20, 182, 171],
#  [3330, 3331, 39, 7, 282, 61, 282, 24, 66, 388, 17, 24, 318],
#  [1, 75, 7, 805, 36, 586, 549, 3332],
#  [3333,
#   9,
#   67,
#   3334,
#   2,
#   3335,
#   237,
#   93,
#   12,
#   173,
#   1508,
#   258,
#   45,
#   23,
#   9,
#   3336,
#   129,
#   33,
#   12,
#   734,
#   43],
#  [8, 24, 918, 126, 60, 3, 310, 9, 919, 5, 2038, 1042, 2031],
#  [1509, 683, 8, 28, 23, 3, 460, 48, 3337, 684, 390, 14, 685, 1, 141, 9],
#  [3338,
#   3339,
#   1,
#   59,
#   154,
#   24,
#   15,
#   115,
#   1,
#   255,
#   5,
#   3340,
#   1,
#   80,
#   2039,
#   920,
#   9,
#   207,
#   1,
#   140,
#   1022,
#   2,
#   157,
#   1038],
#  [3341,
#   137,
#   51,
#   59,
#   3342,
#   64,
#   117,
#   9,
#   3343,
#   51,
#   921,
#   806,
#   290,
#   169,
#   3344,
#   142,
#   78,
#   541,
#   1043],
#  [21, 102, 11, 4, 2040, 29, 55, 2, 903],
#  [3345, 3346, 1, 137, 76, 251, 2, 18, 2041],
#  [3347, 193, 807, 8, 145, 46, 3348, 2, 191, 86, 124],
#  [808,
#   1,
#   141,
#   5,
#   252,
#   29,
#   55,
#   2,
#   1510,
#   550,
#   2,
#   32,
#   2,
#   81,
#   3349,
#   19,
#   349,
#   6,
#   3,
#   3350,
#   8,
#   1043],
#  [1, 75, 5, 3351, 118, 96, 2042, 28, 23, 3, 3352],
#  [3353, 1479, 17, 24, 66, 14, 5, 3354, 31, 16, 1044, 136, 35, 65, 3355],
#  [3356,
#   3357,
#   34,
#   3358,
#   3,
#   1511,
#   2043,
#   3359,
#   6,
#   3360,
#   1045,
#   207,
#   56,
#   9,
#   31,
#   11,
#   3,
#   176,
#   809,
#   354,
#   177,
#   77,
#   7,
#   356],
#  [2044, 33, 12, 5, 240],
#  [2045, 1512, 4, 1513, 10, 5, 1514, 249, 6, 1227, 3, 84, 922, 28, 10, 3361],
#  [3362, 20, 1, 117, 15, 3363, 435, 3364, 2046],
#  [10, 3, 3365, 11, 3366, 272, 28, 3, 735, 1228, 126],
#  [3367, 13, 43, 57, 2, 459, 87, 736, 37, 324, 5, 2047, 2, 1515, 3368, 29],
#  [1229,
#   22,
#   3369,
#   30,
#   325,
#   2,
#   25,
#   2048,
#   3370,
#   38,
#   3371,
#   143,
#   80,
#   26,
#   461,
#   70,
#   340],
#  [3372, 170, 170, 686],
#  [21,
#   57,
#   2,
#   1046,
#   1047,
#   33,
#   12,
#   5,
#   2049,
#   810,
#   2050,
#   149,
#   7,
#   2051,
#   11,
#   3373,
#   2052,
#   10,
#   173,
#   2053],
#  [923, 1, 117, 1230, 37, 305, 1516, 13],
#  [37, 22, 4, 104, 27, 66, 3374, 2, 1203],
#  [3375, 7, 239, 6, 31, 26, 291, 1, 117, 3376, 450, 3377, 3378, 11, 573, 142],
#  [71, 206, 11, 3, 2054, 368, 267, 9, 1, 76, 5, 2055],
#  [3379, 3380, 3381, 1517, 61, 106, 435, 25, 88, 10, 38, 81, 548],
#  [3382,
#   106,
#   20,
#   1,
#   58,
#   25,
#   19,
#   3,
#   2056,
#   3383,
#   10,
#   3,
#   551,
#   20,
#   203,
#   7,
#   68,
#   64,
#   622,
#   60,
#   9,
#   292,
#   1231,
#   2056],
#  [259, 6, 3, 1518, 8, 460],
#  [293,
#   8,
#   2057,
#   86,
#   83,
#   1,
#   22,
#   1519,
#   98,
#   484,
#   334,
#   18,
#   102,
#   1232,
#   1520,
#   10,
#   3384,
#   587,
#   1,
#   46,
#   3,
#   552,
#   2058,
#   10,
#   3385,
#   669,
#   115],
#  [3386,
#   3387,
#   1,
#   141,
#   78,
#   16,
#   687,
#   34,
#   728,
#   200,
#   737,
#   2059,
#   2,
#   209,
#   7,
#   894,
#   423,
#   2060],
#  [924,
#   72,
#   811,
#   1956,
#   72,
#   623,
#   51,
#   2008,
#   72,
#   277,
#   541,
#   2061,
#   812,
#   3388,
#   14,
#   232,
#   247,
#   2062,
#   26,
#   389,
#   55,
#   1,
#   230,
#   1,
#   22,
#   3389,
#   260,
#   61,
#   21,
#   3390,
#   72,
#   268],
#  [3391, 3392, 1, 76, 537, 569, 2063, 15, 289, 207, 688, 119, 52],
#  [5, 271, 8, 38, 4, 2064],
#  [5,
#   735,
#   3393,
#   33,
#   6,
#   8,
#   2065,
#   1233,
#   624,
#   90,
#   44,
#   85,
#   2,
#   34,
#   163,
#   11,
#   157,
#   29,
#   3394,
#   44],
#  [134, 625, 617, 14, 813, 287, 3, 1234, 588, 19, 3395],
#  [722, 11, 925, 1, 67, 135, 95, 231, 72, 100, 153, 266],
#  [42,
#   553,
#   12,
#   2066,
#   42,
#   926,
#   10,
#   3396,
#   3397,
#   66,
#   920,
#   2067,
#   11,
#   4,
#   3398,
#   401,
#   3399,
#   60,
#   3400,
#   1521,
#   11,
#   13,
#   6,
#   178],
#  [3401, 69, 208, 229, 38, 45, 8, 24, 120, 11, 7],
#  [3402,
#   1235,
#   17,
#   56,
#   2068,
#   2069,
#   1,
#   59,
#   54,
#   154,
#   516,
#   60,
#   129,
#   65,
#   738,
#   2070,
#   3403,
#   3,
#   895],
#  [680, 75, 1522, 36, 927, 50, 3404],
#  [3405, 3406, 1048, 8, 187, 29, 20, 68, 39, 3407, 1049],
#  [1, 63, 59, 54, 610, 88, 160, 73, 115, 3408, 14, 3, 537, 124],
#  [928, 28, 14, 73, 357, 1, 75, 1991],
#  [85, 73, 209],
#  [21, 3409, 79, 1523, 45, 115, 6, 2071, 1, 59, 1524],
#  [3410, 1525, 155, 137, 454, 13, 29],
#  [61, 3411, 113],
#  [3412, 174, 8, 3413, 2072, 2073, 2072, 6, 1, 62, 814, 3414, 2, 25, 1526, 44],
#  [3415, 45, 3416, 13, 56, 2074, 172],
#  [1, 75, 270, 3417],
#  [3418, 106, 2, 547, 16, 2, 7],
#  [226, 2, 815, 33, 1236, 6, 2075, 2076],
#  [4,
#   402,
#   133,
#   21,
#   1050,
#   189,
#   136,
#   6,
#   74,
#   279,
#   74,
#   65,
#   12,
#   3,
#   3419,
#   309,
#   1,
#   18,
#   281,
#   57,
#   2,
#   49],
#  [311, 626, 153, 70, 1, 67, 1527, 13, 11, 24, 241, 3420],
#  [8, 115],
#  [33,
#   14,
#   585,
#   1042,
#   12,
#   3421,
#   2077,
#   2078,
#   3422,
#   31,
#   10,
#   1051,
#   3423,
#   14,
#   4,
#   3424,
#   2079,
#   1,
#   230,
#   125,
#   22,
#   579,
#   4,
#   97,
#   816,
#   3425,
#   24,
#   2080,
#   340],
#  [3426, 3427, 74, 618, 4, 148, 739, 1, 2081, 12, 1493, 16, 106],
#  [24, 4, 30, 415, 37],
#  [3428, 1, 436, 1237, 268, 3, 234, 929, 20, 35, 1528],
#  [122,
#   817,
#   1052,
#   27,
#   10,
#   2082,
#   798,
#   6,
#   2083,
#   430,
#   554,
#   56,
#   3429,
#   2084,
#   11,
#   3430,
#   3431,
#   105,
#   3432,
#   3433],
#  [3434, 107],
#  [3435,
#   63,
#   3436,
#   19,
#   930,
#   3437,
#   64,
#   416,
#   81,
#   627,
#   11,
#   7,
#   43,
#   6,
#   111,
#   166,
#   9,
#   2,
#   7,
#   11,
#   41,
#   818],
#  [1, 3438, 121, 3439, 427],
#  [320, 33, 1, 18, 4, 678, 2085],
#  [3440, 78, 62, 1, 122, 77, 7],
#  [19,
#   48,
#   339,
#   42,
#   7,
#   18,
#   197,
#   2086,
#   12,
#   1525,
#   69,
#   135,
#   7,
#   76,
#   2,
#   1053,
#   189,
#   138,
#   16,
#   212,
#   819,
#   12,
#   628,
#   42,
#   3441,
#   2087,
#   820],
#  [3442, 13, 43],
#  [1, 18, 4, 1238, 10, 5, 931, 1, 729, 1, 1054, 4, 2088, 1239],
#  [356, 204, 12, 3, 629, 3443, 3444],
#  [2089, 932, 417, 170, 166, 9, 1, 168, 77, 178],
#  [5, 584, 740, 3445, 1240, 12, 108],
#  [312, 208, 3, 798, 3446, 3447, 1055, 22, 1529, 86],
#  [3448, 3449, 351, 24, 45, 10, 3450],
#  [2090, 54, 610, 2, 41, 1201, 1530, 273, 274, 3451, 1531, 29, 67, 75, 485],
#  [8, 1532, 16, 47, 199, 3452],
#  [89, 216, 821, 624, 3, 3453, 26, 89],
#  [3454, 125, 125, 125, 106, 182, 209, 7, 14, 16, 1, 268, 137, 59, 3455],
#  [310,
#   310,
#   34,
#   207,
#   15,
#   162,
#   23,
#   31,
#   3,
#   3456,
#   321,
#   3457,
#   630,
#   73,
#   822,
#   2091,
#   142,
#   5,
#   2092,
#   2079,
#   1241,
#   8,
#   3458],
#  [3459, 145, 162, 38, 308, 31, 27, 54, 4, 1533],
#  [3460,
#   823,
#   1,
#   1029,
#   54,
#   2093,
#   103,
#   162,
#   23,
#   5,
#   517,
#   909,
#   2094,
#   3,
#   389,
#   202,
#   103,
#   3461],
#  [19, 45],
#  [199,
#   609,
#   269,
#   95,
#   631,
#   65,
#   3462,
#   437,
#   2095,
#   17,
#   2075,
#   2076,
#   14,
#   933,
#   3463,
#   69,
#   70,
#   69,
#   70,
#   69,
#   70,
#   3464],
#  [1,
#   222,
#   1,
#   58,
#   316,
#   2,
#   34,
#   2,
#   108,
#   29,
#   142,
#   136,
#   1,
#   1206,
#   391,
#   56,
#   934,
#   69,
#   70,
#   3465,
#   3466,
#   3467,
#   48,
#   332,
#   632],
#  [3468, 630, 2, 2042, 28, 61, 24, 142, 1056, 2, 25, 187, 930],
#  [1, 137, 59, 54, 2, 49, 400, 26, 8, 33, 12, 1534, 1535],
#  [3469,
#   44,
#   486,
#   41,
#   3470,
#   375,
#   25,
#   3471,
#   251,
#   816,
#   7,
#   143,
#   76,
#   2,
#   34,
#   2,
#   45,
#   37],
#  [3472,
#   17,
#   1057,
#   1242,
#   2,
#   42,
#   1536,
#   3473,
#   42,
#   358,
#   131,
#   5,
#   1537,
#   6,
#   618,
#   3474,
#   88,
#   8,
#   308,
#   30,
#   60,
#   9,
#   576,
#   1058],
#  [3475, 324, 185, 4, 1058, 3476],
#  [3477,
#   689,
#   17,
#   2096,
#   73,
#   240,
#   291,
#   35,
#   517,
#   291,
#   434,
#   216,
#   3478,
#   2,
#   280,
#   14,
#   291,
#   19,
#   2097],
#  [2098, 935, 936, 2, 25, 1538, 44, 36, 114, 50, 3479],
#  [33, 144, 537, 3480, 15, 192],
#  [18, 5, 3481, 553, 10, 3, 89, 61, 15, 937, 16, 61, 122, 454],
#  [35, 3482, 20, 1, 1539, 4, 66, 181, 479, 16, 22, 19, 3, 690, 273, 44],
#  [3483,
#   691,
#   3484,
#   144,
#   28,
#   6,
#   727,
#   624,
#   8,
#   3,
#   193,
#   202,
#   11,
#   13,
#   20,
#   3,
#   487,
#   8,
#   15,
#   113,
#   78,
#   1,
#   32,
#   28,
#   304,
#   824,
#   10,
#   175,
#   329],
#  [89,
#   21,
#   411,
#   28,
#   146,
#   217,
#   20,
#   1,
#   473,
#   108,
#   400,
#   53,
#   2,
#   938,
#   692,
#   4,
#   146,
#   170,
#   1,
#   64,
#   49,
#   16,
#   14,
#   3,
#   518],
#  [3485,
#   17,
#   106,
#   1,
#   66,
#   121,
#   1,
#   183,
#   18,
#   245,
#   9,
#   20,
#   88,
#   22,
#   35,
#   116,
#   1,
#   143,
#   32,
#   2,
#   49,
#   377,
#   1,
#   519,
#   37],
#  [3486, 1, 59, 9, 140, 25, 172, 1, 121, 1243, 119, 52, 2, 3487, 3488],
#  [1540, 1541, 5, 462],
#  [57, 2, 166, 4, 201, 27],
#  [540, 8, 144, 267, 825, 37],
#  [69,
#   5,
#   3489,
#   305,
#   1,
#   21,
#   1059,
#   28,
#   4,
#   2099,
#   373,
#   9,
#   22,
#   73,
#   1244,
#   12,
#   3490,
#   91,
#   3491],
#  [1, 18, 38, 97, 3492, 14, 5, 1060],
#  [3493, 633, 1, 117, 11, 7, 10, 26, 619],
#  [3494,
#   3495,
#   106,
#   106,
#   106,
#   83,
#   7,
#   38,
#   1,
#   183,
#   3496,
#   14,
#   452,
#   2,
#   3497,
#   2,
#   488,
#   247,
#   3498],
#  [183, 24, 1245, 249, 12, 1542, 37, 88, 8, 4, 621, 220, 826],
#  [3499,
#   56,
#   16,
#   238,
#   3,
#   634,
#   299,
#   2,
#   3,
#   458,
#   10,
#   929,
#   259,
#   1,
#   141,
#   156,
#   174,
#   582,
#   28,
#   223,
#   156,
#   17,
#   66,
#   106],
#  [3500, 3501, 8, 185, 3502, 60, 3503, 145, 167, 102, 88],
#  [8, 24, 4, 130, 30, 3504, 15, 741, 77, 91, 105, 520, 3505],
#  [3506, 110, 1, 347, 9, 43, 6, 4, 285, 939, 15, 51, 1543, 574, 482],
#  [630, 189, 2, 49],
#  [8, 201, 2100, 521, 351, 5, 940, 141, 13, 339, 339],
#  [126, 438, 27, 242, 53, 52, 2, 179, 105],
#  [216,
#   130,
#   130,
#   106,
#   11,
#   372,
#   10,
#   3,
#   2101,
#   174,
#   57,
#   541,
#   3507,
#   249,
#   118,
#   16,
#   258,
#   635,
#   2,
#   186],
#  [9, 128, 66, 25, 270, 1061],
#  [3508, 324, 113, 51, 3509, 338, 198],
#  [3510, 110, 1, 22, 941, 283, 1, 143, 77, 7, 893],
#  [8,
#   9,
#   115,
#   16,
#   1,
#   62,
#   353,
#   1246,
#   33,
#   16,
#   42,
#   3511,
#   42,
#   8,
#   430,
#   2,
#   3512,
#   3,
#   158,
#   8,
#   390,
#   20,
#   1,
#   40,
#   9],
#  [26, 84, 103, 102, 2102, 439],
#  [144, 288, 45, 72, 349, 124],
#  [3513, 8, 4, 3514],
#  [3515, 3516, 374, 1062, 2103, 942, 2, 3, 636],
#  [1544, 3517, 3518, 1, 43, 287, 2104, 84, 3519, 943],
#  [3520, 1, 542, 636, 32, 15, 115, 78, 576, 201],
#  [89, 3521, 126, 356, 241, 4, 112, 1063, 27, 218, 45],
#  [612,
#   2,
#   18,
#   4,
#   315,
#   318,
#   14,
#   117,
#   618,
#   2105,
#   3522,
#   21,
#   102,
#   10,
#   572,
#   2,
#   32,
#   1247,
#   3523,
#   144,
#   452,
#   79,
#   29,
#   217,
#   11,
#   323,
#   233],
#  [74, 944, 29, 62, 99, 109, 11, 4, 152, 75, 13, 1248, 945, 945],
#  [3524, 112],
#  [6, 508, 5, 584, 8, 946, 1, 378, 16, 1, 58, 827, 3525, 6, 1, 49, 24, 76],
#  [693,
#   23,
#   186,
#   1024,
#   299,
#   70,
#   37,
#   58,
#   59,
#   3,
#   1545,
#   440,
#   26,
#   152,
#   203,
#   217,
#   176,
#   152],
#  [3526, 127, 13, 43, 1546, 54, 1547, 345, 1547, 3527, 694],
#  [828, 3528, 43, 93, 1064, 2106],
#  [3529,
#   829,
#   3,
#   40,
#   12,
#   41,
#   188,
#   3530,
#   3531,
#   1548,
#   80,
#   1548,
#   12,
#   199,
#   481,
#   13,
#   20,
#   35],
#  [65, 3532, 69, 267, 1, 359, 2, 830, 3, 798, 2, 138, 9, 4, 2107, 742],
#  [3533, 1249, 17, 30, 555, 2108, 1549, 93, 2109, 24, 3, 234, 7, 2110, 1550],
#  [3534,
#   72,
#   4,
#   1065,
#   12,
#   3535,
#   214,
#   825,
#   1250,
#   295,
#   144,
#   288,
#   119,
#   52,
#   72,
#   13,
#   8,
#   14,
#   221,
#   4,
#   300],
#  [1, 141, 922, 28, 217, 6, 24, 211, 510, 2, 34, 52, 2, 108],
#  [611, 3536, 8, 159, 99, 2, 335, 2111, 6, 3537, 111],
#  [1225, 39, 673, 743, 132, 434, 574],
#  [66, 304, 150, 29],
#  [3538,
#   3539,
#   477,
#   1,
#   22,
#   3540,
#   2,
#   3541,
#   3542,
#   1,
#   22,
#   81,
#   3543,
#   1551,
#   111,
#   6,
#   29,
#   61,
#   81,
#   1552,
#   1551,
#   3544,
#   3545,
#   3546,
#   2112],
#  [3547, 1, 82, 1066, 60, 3548, 947],
#  [3549,
#   1,
#   222,
#   7,
#   167,
#   46,
#   16,
#   3550,
#   1251,
#   3551,
#   6,
#   1252,
#   7,
#   160,
#   3552,
#   60,
#   2113,
#   1243,
#   160,
#   33,
#   12,
#   3553],
#  [17, 192, 6, 18, 589, 2114, 105],
#  [1253,
#   1492,
#   948,
#   2,
#   3554,
#   1067,
#   1254,
#   3555,
#   31,
#   5,
#   3556,
#   2,
#   3557,
#   1492,
#   386,
#   71,
#   103,
#   1067,
#   1254,
#   170,
#   17,
#   2115,
#   3,
#   800,
#   1553],
#  [949, 26, 8, 2116, 3, 3558, 432, 3559, 8, 71, 3560, 123, 3, 1503, 3561, 2117],
#  [70,
#   35,
#   3562,
#   197,
#   13,
#   733,
#   277,
#   3,
#   3563,
#   14,
#   48,
#   96,
#   453,
#   38,
#   931,
#   96,
#   426,
#   15,
#   418,
#   16,
#   54,
#   687,
#   78,
#   51,
#   950,
#   1068,
#   38,
#   1,
#   18],
#  [98, 84, 10, 1, 58, 75, 242, 31, 5, 332, 1255],
#  [3564, 1554, 145, 71, 24, 428, 9],
#  [192, 2118, 1555, 3565, 74, 356],
#  [3566, 1256, 99, 16, 3567, 255],
#  [3568, 106, 2119, 1, 80, 51, 85, 73, 3569, 1, 245, 9, 79],
#  [1257,
#   16,
#   17,
#   53,
#   2,
#   18,
#   2,
#   32,
#   28,
#   217,
#   2,
#   590,
#   19,
#   45,
#   237,
#   5,
#   200,
#   695,
#   3570,
#   8,
#   71,
#   3571,
#   28],
#  [1, 75, 1258, 199],
#  [35, 324, 113, 44, 6, 127, 125, 22, 4, 3572, 3573, 44, 3574],
#  [1, 637, 4, 831, 12, 3575, 19, 3, 897, 832, 249, 6, 263, 178, 19, 3, 272, 33],
#  [345, 537, 569, 6, 1252, 1486, 29],
#  [3576,
#   110,
#   127,
#   1,
#   22,
#   516,
#   23,
#   4,
#   243,
#   6,
#   111,
#   696,
#   556,
#   638,
#   5,
#   833,
#   67,
#   355,
#   489,
#   93,
#   744],
#  [3577, 834, 3578, 2120, 11, 2121, 1556],
#  [259, 5, 639, 28, 2122, 143, 45, 17, 4, 1557, 19, 188],
#  [3579,
#   132,
#   8,
#   1043,
#   221,
#   4,
#   951,
#   82,
#   96,
#   453,
#   38,
#   104,
#   2027,
#   3580,
#   36,
#   146,
#   246,
#   3581],
#  [1210, 1, 2123, 3582, 5, 1558, 745, 6, 1, 359, 54, 9, 8, 60],
#  [1, 18, 4, 3583, 189, 10, 5, 1232],
#  [57, 221, 4, 148, 6, 1058, 697],
#  [3584, 2124, 137, 835, 7, 58, 6, 417, 17, 106, 6, 237, 1, 828, 43, 93, 110],
#  [3585,
#   17,
#   167,
#   836,
#   7,
#   86,
#   41,
#   247,
#   8,
#   4,
#   3586,
#   9,
#   347,
#   17,
#   176,
#   6,
#   9,
#   2125,
#   28,
#   14,
#   13,
#   29,
#   1,
#   67,
#   32,
#   7],
#  [3587, 1069, 20, 3, 952, 258, 38, 3, 3588, 3589, 6, 195, 1559, 13],
#  [3590, 1, 18, 35, 1259, 12, 13, 160, 17, 24, 574, 259],
#  [3591, 47, 4, 146, 2126, 3, 3592, 90, 8, 3593, 257, 5, 65, 19, 79],
#  [3594, 351, 41, 735, 1560, 178, 10, 463, 632],
#  [293, 360, 100, 837, 360, 838, 683, 8, 393, 23, 13, 3595],
#  [1, 816, 7, 3596, 3597, 8, 122, 325],
#  [698, 10, 5, 252, 1, 724, 159, 29, 5, 1070, 360],
#  [3598, 5, 3599],
#  [3600, 1, 522, 77, 9],
#  [3601, 127, 68, 2127, 217, 38, 523, 513, 1, 21, 591, 37, 9, 22, 181],
#  [10, 179, 164, 1561, 48, 260, 2128, 439, 27],
#  [301,
#   2,
#   2129,
#   3602,
#   1562,
#   2,
#   3,
#   814,
#   1563,
#   26,
#   89,
#   107,
#   352,
#   3603,
#   245,
#   38,
#   26,
#   400],
#  [3604, 3605, 16, 352, 4, 30, 116, 2, 483, 4, 27],
#  [3606,
#   8,
#   9,
#   101,
#   640,
#   3607,
#   10,
#   3,
#   89,
#   14,
#   3,
#   953,
#   464,
#   1,
#   32,
#   99,
#   269,
#   177,
#   217,
#   37],
#  [61,
#   24,
#   53,
#   2,
#   3608,
#   2,
#   3609,
#   11,
#   3,
#   746,
#   124,
#   1,
#   686,
#   91,
#   1066,
#   31,
#   12,
#   7,
#   39,
#   106],
#  [21, 3610, 16, 125, 103, 35, 954, 2, 166, 11, 228, 3611, 3612, 270, 441],
#  [24, 43, 126, 60, 16],
#  [826, 1, 121, 5, 271, 22, 3613, 86, 1, 66, 163, 38, 145, 4, 3614],
#  [3615,
#   137,
#   32,
#   9,
#   90,
#   10,
#   1496,
#   286,
#   58,
#   9,
#   25,
#   318,
#   2,
#   1564,
#   19,
#   31,
#   1565,
#   40,
#   2,
#   459,
#   9],
#  [8, 1071, 125, 143, 219, 3, 955, 204],
#  [55, 3616, 123, 490, 747, 224, 152, 12, 3617],
#  [748, 27],
#  [3618, 3619, 3620, 3621, 3622, 3623, 3624, 3625, 3626],
#  [91,
#   49,
#   7,
#   273,
#   194,
#   829,
#   2130,
#   14,
#   7,
#   9,
#   3627,
#   13,
#   6,
#   9,
#   284,
#   13,
#   3628,
#   305,
#   155,
#   138,
#   157,
#   273,
#   1,
#   63,
#   117,
#   699,
#   400],
#  [463, 623, 18, 35, 3629, 5, 636],
#  [245, 9, 31, 3, 116, 2, 2131, 1566, 3630, 12, 3, 302, 218, 3, 3631, 1567],
#  [3632, 2132, 213, 22, 172, 66, 20, 43, 113, 2133, 255],
#  [3633, 229, 30, 334, 40, 4, 700, 27, 20, 145, 274, 34, 2, 45, 379, 839],
#  [933,
#   1500,
#   3634,
#   212,
#   1568,
#   3635,
#   58,
#   25,
#   16,
#   98,
#   790,
#   19,
#   3,
#   3636,
#   3637,
#   3638],
#  [10,
#   175,
#   574,
#   86,
#   129,
#   54,
#   687,
#   151,
#   4,
#   148,
#   3639,
#   45,
#   125,
#   724,
#   423,
#   14,
#   3,
#   840,
#   3640,
#   477,
#   260,
#   195,
#   543,
#   346,
#   3641,
#   1072,
#   72],
#  [17, 2024, 38, 380, 9, 369, 388, 26, 313, 12, 536, 101, 687, 2, 156, 38, 13],
#  [1, 359, 5, 736, 23, 5, 3642, 641, 101, 29],
#  [3643,
#   31,
#   89,
#   1569,
#   10,
#   3,
#   1260,
#   2134,
#   14,
#   2,
#   3644,
#   1570,
#   6,
#   841,
#   10,
#   3,
#   551],
#  [69, 5, 3645, 381],
#  [3646,
#   58,
#   301,
#   56,
#   5,
#   247,
#   37,
#   583,
#   2,
#   3647,
#   2,
#   557,
#   3648,
#   19,
#   3,
#   483,
#   12,
#   3,
#   27,
#   35,
#   622,
#   524,
#   11,
#   13,
#   37],
#  [3649, 61, 101, 14, 3650, 44],
#  [3651, 69, 1261, 160, 7, 842, 33, 12, 3, 1571, 1262, 2135],
#  [57, 2136, 60, 3652, 98, 84, 261, 2137, 4, 441, 79],
#  [8, 558, 82, 4, 1263],
#  [3653, 267, 2138, 454, 67, 135, 197, 336],
#  [1,
#   956,
#   78,
#   326,
#   1572,
#   160,
#   60,
#   358,
#   189,
#   1,
#   3654,
#   6,
#   1057,
#   341,
#   843,
#   10,
#   3,
#   89,
#   29,
#   1,
#   355,
#   10,
#   6,
#   45],
#  [57, 2, 3655, 3656, 158, 306, 176, 478, 24, 340, 3657, 3658],
#  [79, 117, 38, 145, 57, 4, 2139, 10, 5, 1264],
#  [21,
#   46,
#   1073,
#   642,
#   103,
#   102,
#   919,
#   6,
#   9,
#   22,
#   53,
#   15,
#   70,
#   746,
#   158,
#   10,
#   738,
#   3659,
#   12,
#   3660],
#  [262, 8, 3661, 1, 75, 157, 1265, 43, 465, 150, 29],
#  [24, 210, 419, 2, 45, 20, 1, 182, 2140, 9, 254, 744],
#  [812, 27, 52, 2, 3662, 74, 130, 200, 142, 5, 2141, 3663, 117, 3664],
#  [1074, 39, 112, 20, 7, 59, 844, 178, 323, 10, 4, 295, 140, 25, 112, 43],
#  [3665, 63, 835, 1573, 3666, 3667, 17, 3668, 1574, 81, 2142],
#  [94, 1575, 1, 40, 7, 104, 104, 2143],
#  [8, 356],
#  [19, 79],
#  [1,
#   21,
#   38,
#   2,
#   49,
#   380,
#   309,
#   6,
#   9,
#   3669,
#   102,
#   43,
#   289,
#   33,
#   1075,
#   413,
#   1,
#   643,
#   442],
#  [91,
#   351,
#   3670,
#   3671,
#   56,
#   3672,
#   1266,
#   38,
#   16,
#   346,
#   172,
#   1,
#   21,
#   538,
#   957,
#   38,
#   157,
#   6,
#   29,
#   1,
#   1576,
#   638,
#   129,
#   24,
#   30],
#  [37,
#   22,
#   30,
#   16,
#   169,
#   196,
#   3673,
#   10,
#   3674,
#   21,
#   13,
#   95,
#   1076,
#   3675,
#   1077,
#   91,
#   275,
#   8,
#   3676,
#   2144,
#   514,
#   238,
#   13,
#   171],
#  [3677, 1, 1050, 16, 101, 151, 1, 3678, 437, 9],
#  [35, 1, 143, 1577, 7, 31, 70, 162, 3679],
#  [366, 74, 944, 1, 137, 117, 70],
#  [3680,
#   1,
#   21,
#   1050,
#   16,
#   3681,
#   39,
#   443,
#   4,
#   644,
#   1078,
#   10,
#   796,
#   184,
#   6,
#   17,
#   1963,
#   2,
#   796,
#   111,
#   1578,
#   33,
#   113,
#   337],
#  [2145, 1, 2146, 3682, 6, 88, 8, 308, 328, 23, 1079, 2, 3683, 5, 3684, 675],
#  [2147,
#   32,
#   10,
#   2,
#   3685,
#   3686,
#   10,
#   3687,
#   403,
#   681,
#   10,
#   3688,
#   1579,
#   3689,
#   587,
#   1267,
#   109,
#   571,
#   215,
#   13,
#   898,
#   178,
#   382],
#  [3690, 348, 3, 749, 67, 34, 33, 23, 3, 750],
#  [1580,
#   387,
#   513,
#   62,
#   259,
#   1,
#   121,
#   1,
#   22,
#   71,
#   423,
#   122,
#   25,
#   4,
#   148,
#   27,
#   19,
#   45],
#  [3691, 35, 1, 137, 80, 15],
#  [3692, 3, 310, 90],
#  [226, 2, 49, 4, 1581, 1268, 14, 1269, 3693, 11, 692],
#  [3694, 261, 46, 4, 267, 525],
#  [8, 71, 2148, 592, 2149, 37],
#  [24, 3695, 1, 62, 106, 1, 18, 101, 21, 46, 52],
#  [3696,
#   107,
#   64,
#   68,
#   24,
#   32,
#   131,
#   291,
#   38,
#   26,
#   812,
#   593,
#   61,
#   24,
#   90,
#   111,
#   15,
#   78,
#   51,
#   32,
#   52,
#   56,
#   232,
#   701,
#   3697,
#   3698,
#   426,
#   51,
#   53,
#   526],
#  [139, 198, 19, 913, 18, 2, 265, 5, 27, 395, 35, 3699],
#  [8, 52, 79, 151, 3700, 55, 19, 302, 5, 302, 3701, 420],
#  [1270,
#   559,
#   294,
#   7,
#   39,
#   241,
#   3702,
#   19,
#   41,
#   158,
#   1,
#   522,
#   135,
#   2,
#   77,
#   7,
#   593,
#   812,
#   121,
#   1,
#   64,
#   557,
#   3703,
#   329,
#   324,
#   4,
#   697],
#  [188, 8, 3704],
#  [3705, 9, 22, 4, 2150, 2151, 244, 3706, 3707, 11, 269, 389, 153],
#  [3708, 508, 249, 5, 540, 558, 9, 21, 46, 1080, 6, 29, 5, 455, 8, 31, 2152],
#  [491],
#  [1582,
#   10,
#   3,
#   89,
#   18,
#   2,
#   25,
#   88,
#   19,
#   2153,
#   259,
#   1,
#   509,
#   63,
#   142,
#   543,
#   28,
#   16,
#   217,
#   11,
#   179,
#   209],
#  [3709, 121, 1, 183, 34, 2, 3, 1061, 18, 1271, 31, 27],
#  [44, 212, 1583, 3710, 17, 4, 3711, 16, 300, 8, 2, 2154],
#  [1584, 1272, 107, 139, 7, 3712, 3, 640, 3713, 3714],
#  [1,
#   80,
#   1585,
#   277,
#   4,
#   3715,
#   14,
#   13,
#   3,
#   3716,
#   12,
#   2155,
#   702,
#   103,
#   3717,
#   86,
#   1586,
#   630,
#   2,
#   3718,
#   5,
#   915],
#  [1, 80, 3719, 3720, 1587, 13, 15, 132, 3721, 751, 132, 258, 76, 2, 34, 124],
#  [54, 4, 439, 27, 8, 425, 88, 2, 622, 3722],
#  [3723, 571, 25, 52, 845, 624, 2156],
#  [949, 66, 304, 31, 1, 64, 25, 1588, 164, 8, 3724, 1550, 6, 109],
#  [3725,
#   129,
#   1081,
#   17,
#   3726,
#   815,
#   33,
#   1,
#   143,
#   142,
#   433,
#   5,
#   560,
#   1,
#   63,
#   80,
#   109,
#   38,
#   13],
#  [411,
#   28,
#   2,
#   4,
#   914,
#   507,
#   3727,
#   361,
#   5,
#   1082,
#   16,
#   9,
#   22,
#   3728,
#   199,
#   10,
#   3,
#   3729,
#   3730,
#   24,
#   3731,
#   12,
#   619],
#  [3732, 6, 1, 230, 24, 211, 510, 2, 108, 306, 269, 62, 22, 113],
#  [47,
#   15,
#   267,
#   200,
#   10,
#   26,
#   1537,
#   43,
#   113,
#   1,
#   18,
#   2,
#   138,
#   28,
#   11,
#   5,
#   3733,
#   3734,
#   12,
#   2157,
#   123,
#   698,
#   10,
#   4,
#   2139,
#   268],
#  [5,
#   1223,
#   3735,
#   21,
#   1032,
#   151,
#   703,
#   12,
#   3736,
#   23,
#   228,
#   3737,
#   3738,
#   228,
#   527,
#   1223,
#   6,
#   1,
#   39,
#   122,
#   75,
#   157],
#  [134, 2158, 1490, 413, 20, 107, 69, 107, 540, 2159, 15, 825],
#  [89,
#   5,
#   678,
#   8,
#   71,
#   577,
#   528,
#   144,
#   201,
#   19,
#   227,
#   9,
#   3739,
#   341,
#   151,
#   3740,
#   310,
#   37,
#   11,
#   3741,
#   3742,
#   27],
#  [1273, 17, 162, 23, 109, 35, 65, 1, 59, 2160, 2161, 103, 9, 15, 348, 9],
#  [3743,
#   1,
#   80,
#   3,
#   1274,
#   3744,
#   5,
#   240,
#   4,
#   594,
#   146,
#   1,
#   473,
#   32,
#   254,
#   30,
#   108,
#   151,
#   16],
#  [1,
#   1589,
#   117,
#   201,
#   437,
#   157,
#   1,
#   141,
#   16,
#   68,
#   67,
#   25,
#   645,
#   1,
#   21,
#   75,
#   157,
#   15,
#   93,
#   17,
#   122,
#   34,
#   2010,
#   290,
#   4,
#   795,
#   6,
#   1590],
#  [3745,
#   7,
#   57,
#   4,
#   104,
#   441,
#   329,
#   1,
#   3746,
#   7,
#   17,
#   21,
#   122,
#   25,
#   10,
#   3,
#   803,
#   48,
#   342,
#   4,
#   402,
#   70,
#   47,
#   507,
#   120,
#   492,
#   3747,
#   611],
#  [57, 4, 638, 553, 37],
#  [3748,
#   1,
#   63,
#   646,
#   262,
#   20,
#   1,
#   362,
#   102,
#   2,
#   3749,
#   10,
#   38,
#   626,
#   578,
#   15,
#   16,
#   253,
#   25,
#   181,
#   74,
#   1591,
#   90,
#   43],
#  [3750,
#   17,
#   846,
#   266,
#   6,
#   3,
#   3751,
#   3752,
#   11,
#   912,
#   919,
#   379,
#   3,
#   1275,
#   1,
#   167,
#   428,
#   9,
#   286],
#  [3753, 170, 60, 3, 3754, 3755, 3, 3756, 12, 3757, 136],
#  [117,
#   383,
#   113,
#   1,
#   46,
#   2162,
#   201,
#   29,
#   17,
#   19,
#   45,
#   6,
#   346,
#   19,
#   5,
#   416,
#   226,
#   2,
#   1020,
#   444,
#   2,
#   3758,
#   2162],
#  [3759,
#   3760,
#   689,
#   16,
#   326,
#   84,
#   958,
#   8,
#   35,
#   744,
#   14,
#   5,
#   3761,
#   2163,
#   39,
#   3762,
#   3763],
#  [752,
#   959,
#   155,
#   811,
#   52,
#   1,
#   40,
#   7,
#   15,
#   93,
#   155,
#   3764,
#   126,
#   11,
#   101,
#   4,
#   546,
#   11,
#   13,
#   959,
#   155],
#  [698, 14, 3, 1592, 284, 13, 75, 1593],
#  [3765,
#   110,
#   35,
#   116,
#   1,
#   57,
#   35,
#   476,
#   1,
#   63,
#   421,
#   5,
#   493,
#   1,
#   101,
#   421,
#   9,
#   2,
#   427,
#   2,
#   3766,
#   44],
#  [1,
#   75,
#   5,
#   847,
#   332,
#   1594,
#   110,
#   3767,
#   12,
#   3,
#   847,
#   3768,
#   96,
#   276,
#   3769,
#   51,
#   24,
#   4,
#   3770,
#   163,
#   3771,
#   11,
#   677,
#   2164,
#   3772,
#   3773],
#  [67, 612, 2, 3774, 99, 3, 910],
#  [3775, 13, 2165],
#  [67,
#   108,
#   1,
#   848,
#   3776,
#   252,
#   1276,
#   14,
#   5,
#   3777,
#   2166,
#   6,
#   29,
#   74,
#   10,
#   3778,
#   487,
#   6,
#   3779],
#  [3780,
#   8,
#   5,
#   87,
#   1595,
#   132,
#   2167,
#   3781,
#   6,
#   275,
#   3782,
#   561,
#   8,
#   456,
#   6,
#   937,
#   19,
#   3,
#   234,
#   55],
#  [287, 3, 3783, 753],
#  [5, 3784, 333, 5, 561, 3785, 132, 57, 1277, 3786],
#  [3787, 1, 256, 57, 3, 393, 55, 3, 213, 8, 105, 6, 1, 45, 111, 849],
#  [104,
#   158,
#   124,
#   57,
#   4,
#   104,
#   55,
#   151,
#   82,
#   70,
#   1,
#   141,
#   5,
#   175,
#   136,
#   6,
#   1,
#   75,
#   3,
#   738,
#   704,
#   2168,
#   175,
#   6,
#   2169,
#   357],
#  [3788, 4, 30, 1083, 3, 101, 202, 8, 16, 125, 57, 2, 34, 52, 79],
#  [754, 61, 28, 15, 217, 156, 85, 2, 3789, 922, 13, 28],
#  [3790, 3791, 1278, 363, 20, 466, 1596, 40, 8, 100, 40, 3792],
#  [68,
#   76,
#   3793,
#   36,
#   404,
#   50,
#   3794,
#   3795,
#   1597,
#   467,
#   35,
#   3796,
#   1279,
#   136,
#   36,
#   404,
#   50,
#   3797],
#  [3798, 3799, 3800, 420],
#  [3801, 2, 3802, 75, 7, 239],
#  [705, 3803, 91, 8, 132, 164, 14, 9, 1, 3804, 3805, 2, 92, 10, 1023],
#  [579, 5, 960, 163, 1084, 346, 275, 35, 2170, 54, 147, 97],
#  [1,
#   21,
#   2171,
#   3,
#   1494,
#   12,
#   5,
#   931,
#   1,
#   63,
#   18,
#   585,
#   2,
#   459,
#   87,
#   1085,
#   382,
#   3806],
#  [3807, 1, 1598, 51, 3, 223, 27, 6, 51, 143, 1040, 451, 28, 23, 16],
#  [93, 133, 410, 1, 307, 157, 20, 1, 199, 75, 157, 348],
#  [21, 46, 79, 3808, 33],
#  [3809, 234, 90, 174, 755],
#  [78, 2172, 3810, 14, 2173, 351, 24, 45, 14, 3811, 9, 3812, 13],
#  [3,
#   310,
#   103,
#   789,
#   90,
#   10,
#   2174,
#   9,
#   22,
#   112,
#   295,
#   9,
#   3813,
#   9,
#   235,
#   3814,
#   309,
#   159,
#   3815],
#  [143,
#   108,
#   70,
#   24,
#   28,
#   2,
#   3816,
#   15,
#   1,
#   63,
#   80,
#   37,
#   16,
#   5,
#   1599,
#   8,
#   53,
#   2,
#   34,
#   130,
#   289],
#  [3817,
#   56,
#   3,
#   468,
#   16,
#   81,
#   809,
#   6,
#   4,
#   349,
#   394,
#   214,
#   39,
#   2,
#   25,
#   3818,
#   23,
#   3819,
#   1560,
#   203,
#   9,
#   128,
#   25,
#   3,
#   615,
#   10,
#   3,
#   3820],
#  [494, 450, 1, 63, 80, 17, 460, 199],
#  [3821, 69, 3822, 850, 78, 756, 245, 3823, 165, 1, 609, 7, 3824, 26, 89],
#  [3825,
#   2175,
#   17,
#   24,
#   235,
#   83,
#   47,
#   3,
#   212,
#   354,
#   1051,
#   212,
#   387,
#   202,
#   16,
#   2176,
#   3,
#   706,
#   145,
#   57,
#   15,
#   278,
#   47,
#   279,
#   2,
#   59,
#   54,
#   2176,
#   54],
#  [1, 62, 456, 12, 3826, 1600, 1, 76, 65, 23, 695, 3827],
#  [944, 3828, 354, 849, 1, 128, 18, 3829],
#  [3830, 188, 58, 25, 133, 184],
#  [15, 315, 37, 507, 216, 4, 146, 495, 56, 31, 26, 315],
#  [17,
#   757,
#   3831,
#   1203,
#   17,
#   24,
#   81,
#   1601,
#   1,
#   21,
#   85,
#   5,
#   3832,
#   1,
#   168,
#   728,
#   20,
#   334,
#   141,
#   72,
#   45,
#   268,
#   28,
#   3833,
#   197,
#   4,
#   215,
#   159],
#  [2177, 78, 1, 108, 33, 1280, 79, 3834, 3835],
#  [554, 8, 681, 6, 156, 39, 1257, 16, 1, 558, 9, 949],
#  [3836, 44, 3837, 308, 208, 61, 15, 304, 44],
#  [1086,
#   21,
#   1087,
#   1032,
#   3838,
#   2178,
#   1253,
#   1,
#   40,
#   178,
#   20,
#   96,
#   612,
#   2,
#   25,
#   330,
#   2179,
#   14,
#   1602,
#   13,
#   17,
#   562,
#   142,
#   123,
#   4,
#   1034,
#   1281],
#  [2180, 107, 352, 2180, 746, 14],
#  [189, 103, 102, 1282, 56, 1520, 851, 12, 13],
#  [3, 1603, 6, 3, 1283, 3839, 197, 3840, 3841, 3842, 3843, 3844],
#  [353, 2118, 47, 528, 53, 2, 25, 65, 12, 372, 153],
#  [3845, 65, 12, 5, 2181, 724, 10, 5, 961, 12, 1604],
#  [3846, 1, 66, 76, 2, 647, 7, 14, 3847, 20, 1, 63, 91, 91, 95, 78],
#  [1, 63, 76, 2, 34, 2, 45, 6, 374, 5, 333, 79, 123, 3848],
#  [3849, 2089, 3850, 3851, 19, 3, 1605, 489, 36, 563, 50, 266, 3852],
#  [3853, 170, 1, 962, 51, 160, 3854, 3855],
#  [349,
#   153,
#   2,
#   1020,
#   56,
#   3856,
#   3857,
#   56,
#   29,
#   58,
#   405,
#   13,
#   60,
#   97,
#   153,
#   2,
#   452,
#   11,
#   3,
#   3858],
#  [3859, 1, 63, 76, 2, 163, 275, 1, 85, 4, 1284, 3860, 138, 131, 2, 3861],
#  [3862, 3863, 2182, 3864, 3865],
#  [21, 46, 518, 52, 20, 1, 71, 85, 2, 166, 9, 52, 86],
#  [169, 3866, 496, 8, 24, 15, 93, 382, 20, 1, 3867, 3, 418, 3868],
#  [5, 3869, 2183, 3870, 67, 497, 14, 9],
#  [442, 690, 558, 159, 15, 58, 25, 440, 2, 469, 3871, 27, 29, 454],
#  [3872, 74, 198],
#  [3873, 467, 1, 3874, 52, 197, 2184],
#  [118, 41, 363],
#  [3875,
#   3876,
#   466,
#   1,
#   117,
#   38,
#   68,
#   18,
#   72,
#   354,
#   675,
#   12,
#   1285,
#   1286,
#   173,
#   240,
#   6,
#   3,
#   3877,
#   1606],
#  [5, 616, 9, 8, 2185],
#  [8,
#   516,
#   2,
#   4,
#   243,
#   14,
#   3,
#   247,
#   700,
#   6,
#   3878,
#   23,
#   4,
#   243,
#   3879,
#   648,
#   1,
#   63,
#   1607,
#   425,
#   227,
#   12,
#   31,
#   13],
#  [3880,
#   1,
#   64,
#   101,
#   1287,
#   54,
#   9,
#   253,
#   18,
#   3881,
#   83,
#   1608,
#   2,
#   3882,
#   2186,
#   125,
#   143,
#   1609,
#   16,
#   325,
#   2187,
#   3883],
#  [190,
#   456,
#   16,
#   3884,
#   8,
#   19,
#   2188,
#   150,
#   29,
#   78,
#   1,
#   18,
#   2,
#   34,
#   2,
#   179,
#   24,
#   181,
#   208],
#  [70, 843, 731, 12, 226, 2, 32, 3885, 6, 71, 4, 35, 34, 54, 3, 330, 8, 393],
#  [3886, 3887, 842, 20, 1, 66, 1610],
#  [3888,
#   324,
#   54,
#   1,
#   230,
#   208,
#   13,
#   6,
#   5,
#   243,
#   519,
#   2,
#   34,
#   77,
#   92,
#   20,
#   22,
#   24,
#   235,
#   83,
#   9,
#   22,
#   3,
#   234,
#   65,
#   641,
#   13,
#   2189,
#   35],
#  [1, 76, 5, 3889, 162],
#  [1541, 3890, 808, 209, 13],
#  [579, 268, 288, 11, 179, 63, 117, 38, 53, 20, 18, 269, 1074],
#  [225,
#   47,
#   498,
#   10,
#   2190,
#   69,
#   70,
#   68,
#   58,
#   580,
#   34,
#   3,
#   3,
#   3891,
#   11,
#   649,
#   3892,
#   492],
#  [1, 168, 557, 3, 625, 617],
#  [507, 345, 2, 34, 619, 28, 3893, 6, 138, 4, 200, 561, 3894],
#  [852, 360],
#  [46,
#   2,
#   817,
#   5,
#   89,
#   10,
#   3,
#   2191,
#   5,
#   735,
#   921,
#   5,
#   3895,
#   23,
#   228,
#   52,
#   2192,
#   57,
#   2,
#   32,
#   4,
#   3896,
#   963,
#   43],
#  [1, 75, 39, 188, 758, 554, 396, 2, 25, 595, 91, 139, 9, 32, 1288],
#  [3897, 12, 650, 2, 3, 1289, 20, 24, 3898, 2193, 268],
#  [15, 61, 19, 45, 6, 74, 15, 825, 3899, 3900],
#  [3901, 101, 11, 3, 2194, 3902, 489, 819, 316, 86, 105],
#  [3903,
#   17,
#   106,
#   350,
#   39,
#   66,
#   1596,
#   21,
#   29,
#   118,
#   309,
#   639,
#   28,
#   11,
#   7,
#   130,
#   184],
#  [3904, 754, 106, 3905, 759, 88],
#  [310, 131, 3906],
#  [841, 733, 348],
#  [722, 11, 4, 480, 16, 8, 53, 2, 25, 3, 1039, 12, 13],
#  [3907, 267, 1, 22, 21, 844, 88, 1, 143, 77, 254, 3908],
#  [1, 141, 241, 638, 1074, 284, 13, 117, 3909, 6, 5, 1611, 34, 31, 3910],
#  [3911, 330, 35, 96, 46, 41, 3912, 797],
#  [3913,
#   127,
#   1,
#   59,
#   5,
#   3914,
#   8,
#   19,
#   3,
#   3915,
#   24,
#   19,
#   7,
#   95,
#   3916,
#   289,
#   100,
#   1284,
#   1290,
#   10,
#   3,
#   364,
#   257,
#   3917,
#   4,
#   3918],
#  [3919, 47, 24, 1088, 2, 77, 41, 158, 78, 1, 314, 10, 3920],
#  [3921,
#   726,
#   1,
#   434,
#   288,
#   340,
#   1,
#   101,
#   46,
#   2,
#   191,
#   3,
#   2195,
#   2196,
#   338,
#   529,
#   1,
#   2197,
#   11,
#   4,
#   964,
#   12,
#   523,
#   177,
#   37],
#  [170, 3922, 445, 49, 51, 59, 78, 3923, 87, 853, 58, 1612, 1, 75, 178, 15, 93],
#  [3924,
#   1,
#   77,
#   1,
#   32,
#   2,
#   674,
#   90,
#   10,
#   5,
#   1291,
#   524,
#   134,
#   65,
#   1613,
#   3925,
#   123,
#   2198,
#   1292,
#   295,
#   3926,
#   694,
#   2,
#   34,
#   297],
#  [721, 156, 39, 397, 2, 3, 1089],
#  [3927, 145, 167, 102, 2, 1293, 1, 85, 2, 854, 26],
#  [36, 3928, 50, 3929, 100, 2114, 17, 906],
#  [467, 3930, 74, 498, 36, 563, 50, 266, 3931],
#  [1294, 33, 107, 156, 185, 18, 2, 335, 343, 43, 1072],
#  [792, 5, 3932, 332, 632, 6, 965, 2199, 1614, 58, 75, 7, 2200, 6, 15, 58, 1],
#  [2201, 182, 32, 4, 458, 14],
#  [3933, 7, 128, 18, 2202, 2, 13, 204, 1, 255, 16, 816, 29, 110],
#  [3934,
#   127,
#   74,
#   380,
#   6,
#   127,
#   1,
#   59,
#   3935,
#   173,
#   3936,
#   26,
#   522,
#   25,
#   1615,
#   2203,
#   57,
#   278,
#   2204,
#   3937],
#  [538, 72, 138, 4, 3938, 3939, 20, 1, 137, 59, 83, 9, 1616],
#  [287,
#   3,
#   3940,
#   746,
#   158,
#   11,
#   45,
#   6,
#   201,
#   3941,
#   206,
#   2,
#   225,
#   83,
#   1,
#   85,
#   2,
#   3942,
#   157,
#   2,
#   3943,
#   3944],
#  [1,
#   22,
#   650,
#   72,
#   444,
#   5,
#   3945,
#   2205,
#   101,
#   72,
#   219,
#   9,
#   22,
#   3946,
#   3947,
#   966,
#   3948,
#   351,
#   643,
#   2206,
#   68,
#   182,
#   338,
#   180],
#  [81, 548, 292, 6, 17, 10, 3, 1617, 3949, 71, 4, 146, 3950],
#  [3951, 74, 410, 96, 3952, 1618, 3, 3953, 1064, 216],
#  [1090,
#   819,
#   145,
#   538,
#   103,
#   3954,
#   1619,
#   263,
#   151,
#   126,
#   548,
#   58,
#   316,
#   2,
#   45,
#   10,
#   3,
#   673,
#   1063,
#   12,
#   5,
#   79,
#   302,
#   1,
#   75,
#   3955],
#  [21,
#   519,
#   31,
#   2,
#   59,
#   16,
#   1,
#   255,
#   5,
#   336,
#   10,
#   1209,
#   15,
#   35,
#   109,
#   95,
#   641,
#   2207,
#   194,
#   2208,
#   9,
#   10,
#   1,
#   59,
#   99,
#   2,
#   2209,
#   79],
#  [47, 5, 98, 27, 19, 3956, 746],
#  [1,
#   140,
#   38,
#   2,
#   34,
#   77,
#   3957,
#   6,
#   2210,
#   6,
#   3958,
#   3,
#   223,
#   65,
#   20,
#   139,
#   24,
#   32,
#   753],
#  [1620, 41, 2211, 36, 563, 50, 266, 3959],
#  [1, 21, 1091, 6, 3960, 131, 4, 3961, 6, 398, 5, 3962, 14, 3, 2212],
#  [117, 383, 201, 86],
#  [244, 5, 735, 21, 3963, 4, 270, 12, 3964, 16, 314, 10, 173, 2053],
#  [3965, 13, 43],
#  [19, 45],
#  [5, 458, 195, 745],
#  [411, 28, 23, 3, 855, 487, 2213, 3966, 1498, 10, 5, 389, 293, 360],
#  [69,
#   156,
#   373,
#   60,
#   3,
#   1240,
#   12,
#   108,
#   17,
#   60,
#   2,
#   32,
#   2214,
#   13,
#   6,
#   35,
#   3967,
#   14,
#   3,
#   642,
#   85,
#   2,
#   34,
#   2,
#   175,
#   151,
#   3968],
#  [8, 201, 42, 570, 45, 3969, 147, 97, 20, 1621, 26, 390],
#  [71,
#   2215,
#   1,
#   167,
#   57,
#   3,
#   2029,
#   2,
#   34,
#   319,
#   3970,
#   91,
#   93,
#   1,
#   40,
#   92,
#   19,
#   3971,
#   1092,
#   1978,
#   2216,
#   3,
#   3972,
#   14,
#   326,
#   13,
#   3973,
#   1295],
#  [1025, 3, 240, 258, 16, 643, 38, 760, 120],
#  [3974,
#   112,
#   91,
#   22,
#   3,
#   588,
#   10,
#   3975,
#   1,
#   519,
#   72,
#   34,
#   3976,
#   113,
#   20,
#   1,
#   57,
#   72,
#   45],
#  [3977, 2050, 15, 1064, 1, 62, 15, 106, 16, 610, 2, 7],
#  [3978,
#   127,
#   9,
#   8,
#   20,
#   1,
#   1054,
#   38,
#   1622,
#   9,
#   6,
#   35,
#   65,
#   446,
#   1579,
#   3979,
#   140,
#   2217,
#   13],
#  [1, 121, 2218, 196, 22, 14],
#  [3980, 36, 114, 50, 3981, 16, 8, 115, 1, 670, 386, 65, 396, 2, 25, 496],
#  [3982, 20, 3983],
#  [303, 52, 10, 3, 3984, 1623, 8, 35, 120, 967, 8, 4, 220, 2219],
#  [35, 221, 202, 82, 354, 3985],
#  [3986, 3987, 1, 168, 77, 9],
#  [43, 192, 37],
#  [83,
#   74,
#   3,
#   479,
#   1,
#   80,
#   9,
#   8,
#   107,
#   3,
#   348,
#   39,
#   96,
#   511,
#   4,
#   3988,
#   83,
#   24,
#   2220,
#   61,
#   106,
#   44,
#   1,
#   137,
#   639,
#   28,
#   3989,
#   968],
#  [856, 37, 8, 43, 112, 12, 4, 27, 2, 117, 26, 116],
#  [83,
#   1,
#   57,
#   3990,
#   1,
#   140,
#   335,
#   1624,
#   3991,
#   6,
#   291,
#   61,
#   937,
#   12,
#   475,
#   5,
#   585,
#   83,
#   1,
#   85,
#   9,
#   292,
#   44],
#  [3992,
#   35,
#   17,
#   906,
#   24,
#   20,
#   34,
#   90,
#   36,
#   3993,
#   2221,
#   50,
#   3994,
#   1093,
#   6,
#   88,
#   128,
#   71,
#   25,
#   73,
#   14,
#   3995],
#  [3996, 3997, 707, 198, 391, 9, 22, 365, 20, 689, 47, 24, 1094, 10, 1095],
#  [3998,
#   2222,
#   147,
#   97,
#   147,
#   97,
#   147,
#   97,
#   3999,
#   2223,
#   37,
#   521,
#   113,
#   499,
#   136,
#   692,
#   499,
#   105,
#   526],
#  [74, 167, 11, 13, 2, 25, 1958, 192, 19, 4, 4000, 1625],
#  [1096, 1589, 107, 139, 7, 415, 596, 5, 252, 29, 61, 4, 4001, 208, 1968, 2224],
#  [4002, 3, 634, 351, 24, 45],
#  [500,
#   851,
#   1971,
#   3,
#   4003,
#   220,
#   8,
#   361,
#   24,
#   148,
#   4004,
#   173,
#   1097,
#   8,
#   33,
#   329,
#   1098,
#   857,
#   526],
#  [14,
#   3,
#   116,
#   2,
#   3,
#   761,
#   19,
#   227,
#   26,
#   55,
#   3,
#   4005,
#   24,
#   14,
#   13,
#   2,
#   113,
#   160,
#   53,
#   2,
#   4006,
#   4007,
#   761],
#  [20, 4008, 4009, 8, 530, 969, 190, 36, 404, 50, 4010, 1, 141, 7, 4011],
#  [4012, 15, 456, 4013, 258, 119, 762],
#  [4014, 792, 1, 22, 19, 3, 2225, 241, 4, 728, 69, 135, 71, 201],
#  [5, 470, 763, 46, 2226, 123, 4, 1626, 14, 92, 810, 15, 4015, 970],
#  [1, 141, 2227, 145, 57, 178, 31, 27],
#  [4016, 7, 167, 2228, 13],
#  [4017,
#   6,
#   1,
#   57,
#   120,
#   19,
#   3,
#   2229,
#   37,
#   111,
#   68,
#   299,
#   2,
#   406,
#   6,
#   111,
#   3,
#   1289,
#   1,
#   46,
#   4,
#   852,
#   19,
#   3,
#   2229,
#   136],
#  [35, 4018, 9, 8, 43, 4019, 167, 651, 298, 205, 23, 527, 492],
#  [198, 15, 61, 31, 123, 5, 4020, 115, 350],
#  [4021,
#   16,
#   8,
#   83,
#   17,
#   24,
#   465,
#   4022,
#   2230,
#   1,
#   391,
#   54,
#   7,
#   80,
#   12,
#   173,
#   4023,
#   2163],
#  [226,
#   2,
#   119,
#   2,
#   1627,
#   23,
#   3,
#   708,
#   16,
#   1,
#   35,
#   744,
#   612,
#   2,
#   379,
#   1296,
#   129,
#   4,
#   146,
#   2231,
#   352,
#   9],
#  [826,
#   229,
#   38,
#   194,
#   8,
#   4024,
#   19,
#   5,
#   1276,
#   23,
#   4,
#   4025,
#   35,
#   108,
#   11,
#   13,
#   26,
#   89,
#   17,
#   130,
#   1628,
#   29],
#  [9, 8, 4026, 112, 361, 544, 274, 25, 189, 2, 49, 37, 1, 76, 73, 4027],
#  [28,
#   19,
#   432,
#   62,
#   2,
#   497,
#   5,
#   2232,
#   21,
#   2233,
#   5,
#   2,
#   49,
#   1297,
#   56,
#   3,
#   597,
#   546,
#   17,
#   81,
#   4028,
#   1099],
#  [67, 32, 290, 2155, 87, 300],
#  [5, 947, 2234, 105, 70, 37, 256, 1100, 15, 115],
#  [559,
#   4029,
#   8,
#   99,
#   14,
#   228,
#   480,
#   1629,
#   2235,
#   2236,
#   2237,
#   10,
#   3,
#   902,
#   559,
#   1212,
#   207,
#   249],
#  [69,
#   5,
#   54,
#   4,
#   84,
#   110,
#   4030,
#   6,
#   1,
#   39,
#   1298,
#   4031,
#   306,
#   197,
#   2,
#   405,
#   5,
#   501,
#   92,
#   2238,
#   132,
#   103,
#   2,
#   45,
#   66,
#   217,
#   37],
#  [311,
#   74,
#   256,
#   102,
#   4,
#   148,
#   27,
#   1,
#   76,
#   4,
#   2239,
#   6,
#   1,
#   141,
#   7,
#   445,
#   598,
#   7,
#   232,
#   599,
#   26,
#   6,
#   1,
#   141,
#   7],
#  [283,
#   4032,
#   4033,
#   16,
#   9,
#   8,
#   64,
#   7,
#   2240,
#   9,
#   2,
#   13,
#   136,
#   2241,
#   41,
#   2242,
#   56,
#   4034,
#   105],
#  [27, 12, 1630, 4035, 6, 2243, 1201],
#  [2244, 4036, 51, 4037, 13, 33, 4038],
#  [5, 357, 8, 1101, 4039],
#  [5, 188, 8, 4040, 28, 29, 471, 202, 270, 180, 1631, 808],
#  [4041, 267],
#  [4, 529, 71, 24, 187],
#  [1, 80, 5, 2007, 8, 681],
#  [107, 351, 37, 117, 38, 74, 122, 25, 4, 113, 27],
#  [4042, 4043, 453, 66, 2245],
#  [1210,
#   19,
#   48,
#   339,
#   1632,
#   1,
#   473,
#   421,
#   3,
#   4044,
#   1254,
#   336,
#   1299,
#   95,
#   238,
#   6,
#   1,
#   57,
#   460,
#   1633,
#   1300,
#   144,
#   42,
#   35,
#   540,
#   2159,
#   42,
#   1634],
#  [4045, 4046, 1, 40, 240, 31, 12, 5, 1301, 1078, 18, 4047, 47, 971, 136],
#  [4048,
#   110,
#   234,
#   90,
#   1,
#   18,
#   4,
#   1102,
#   297,
#   2,
#   34,
#   2,
#   14,
#   326,
#   84,
#   478,
#   89,
#   58,
#   25,
#   2246,
#   1476,
#   192,
#   113,
#   4049],
#  [1227, 60, 72, 177, 10, 4050, 26, 205],
#  [4051, 1, 80, 1, 64, 101, 2247, 4, 1302, 2248, 10, 1235, 35, 240, 11, 13],
#  [1, 62, 2249, 91, 93, 1, 141, 231, 619, 858, 52, 79],
#  [21, 230, 60, 91, 1635, 97, 623, 18, 102, 72, 13, 260, 46, 1071, 86, 1636],
#  [27,
#   99,
#   12,
#   45,
#   105,
#   174,
#   729,
#   636,
#   32,
#   4052,
#   1303,
#   2250,
#   99,
#   20,
#   17,
#   4053,
#   105,
#   508,
#   615,
#   71,
#   18,
#   2,
#   45],
#  [5, 336, 252, 955, 558, 15, 115],
#  [611, 242, 8, 211, 849, 29],
#  [1, 18, 4, 915, 1637, 447, 4054, 147],
#  [4055,
#   1,
#   75,
#   7,
#   527,
#   147,
#   97,
#   1,
#   342,
#   26,
#   1638,
#   4056,
#   10,
#   41,
#   1607,
#   88,
#   58,
#   25,
#   81,
#   1304,
#   2251,
#   10,
#   5,
#   403,
#   6,
#   14,
#   5,
#   2252],
#  [19, 45],
#  [4057, 69, 17, 106, 1, 143, 59],
#  [35,
#   509,
#   54,
#   313,
#   12,
#   201,
#   213,
#   12,
#   42,
#   2253,
#   2101,
#   42,
#   8,
#   26,
#   4,
#   42,
#   398,
#   95,
#   75,
#   42,
#   313,
#   12,
#   1103,
#   53,
#   14,
#   6,
#   1,
#   63,
#   38,
#   9],
#  [4058,
#   149,
#   7,
#   57,
#   4,
#   163,
#   26,
#   89,
#   6,
#   54,
#   1,
#   76,
#   8,
#   33,
#   12,
#   2254,
#   58,
#   272,
#   86,
#   184],
#  [187,
#   31,
#   27,
#   14,
#   972,
#   4059,
#   20,
#   1,
#   263,
#   5,
#   1033,
#   4,
#   112,
#   859,
#   11,
#   78,
#   96,
#   32,
#   52],
#  [206, 11, 5, 1639, 2, 273, 211, 4060, 21, 46, 5, 1031, 52, 35, 4061, 263],
#  [263, 5, 247, 19, 4062, 35, 1640, 11, 4, 389, 1221, 177],
#  [4063,
#   165,
#   4064,
#   155,
#   63,
#   141,
#   14,
#   13,
#   1,
#   38,
#   2,
#   265,
#   1636,
#   207,
#   1,
#   18,
#   43,
#   278,
#   4065,
#   11,
#   3,
#   1641,
#   86,
#   40,
#   251,
#   4066],
#  [5, 4067, 2255, 97, 36, 4068, 2256, 266, 4069],
#  [4070,
#   140,
#   40,
#   2,
#   1642,
#   159,
#   11,
#   406,
#   20,
#   24,
#   122,
#   635,
#   37,
#   49,
#   7,
#   49,
#   26,
#   471,
#   152],
#  [259, 1, 141, 187, 15, 192],
#  [103, 21, 162, 3, 1630, 28, 11, 5, 691, 6, 21, 46, 5, 810, 4071, 23, 695],
#  [124,
#   19,
#   1104,
#   1643,
#   409,
#   4072,
#   4073,
#   23,
#   4074,
#   4075,
#   2257,
#   10,
#   4076,
#   4077,
#   398,
#   2258,
#   4078,
#   30,
#   35,
#   4079,
#   263],
#  [2259, 845, 105, 5, 98, 27, 10, 3, 4080],
#  [4081, 4082, 521, 429, 1, 138, 16, 1297, 44],
#  [4083, 4084, 66, 2009, 29, 222, 3, 4085, 4, 4086, 33],
#  [1, 80, 1, 276, 18, 1288, 4, 2260, 26, 152, 123, 144, 4087, 207],
# ...
#   2046,
#   312,
#   16,
#   8,
#   115,
#   1,
#   758,
#   14,
#   211,
#   14,
#   552,
#   12,
#   9,
#   31,
#   111,
#   187,
#   33,
#   151],
#  [4396, 4397, 451, 393, 447, 147],
#  [934,
#   7,
#   431,
#   5,
#   651,
#   12,
#   4398,
#   11,
#   4,
#   4399,
#   69,
#   1666,
#   8,
#   52,
#   29,
#   20,
#   94,
#   11,
#   16,
#   1694,
#   547],
#  [4400, 493, 111, 175],
#  [4401,
#   18,
#   2171,
#   33,
#   3,
#   2354,
#   215,
#   3,
#   2355,
#   1124,
#   24,
#   189,
#   7,
#   1333,
#   2,
#   18,
#   635,
#   10,
#   4,
#   87,
#   240],
#  [53,
#   207,
#   2,
#   1660,
#   11,
#   269,
#   731,
#   53,
#   2,
#   75,
#   5,
#   2281,
#   5,
#   180,
#   6,
#   3,
#   803,
#   16,
#   1,
#   2356],
#  [4402,
#   203,
#   1,
#   34,
#   14,
#   4,
#   146,
#   838,
#   43,
#   29,
#   203,
#   68,
#   128,
#   1046,
#   10,
#   4,
#   1065,
#   12,
#   1695,
#   87,
#   367,
#   54,
#   183,
#   3,
#   1120,
#   977,
#   338],
#  [8, 201, 6, 1620, 4403],
#  [37,
#   22,
#   1101,
#   963,
#   20,
#   307,
#   5,
#   193,
#   243,
#   11,
#   4,
#   285,
#   105,
#   66,
#   465,
#   23,
#   180,
#   48,
#   501,
#   35,
#   491,
#   162,
#   1616,
#   124],
#  [19, 4404, 775, 642, 1334, 123, 4405, 4406],
#  [55, 2, 49, 3, 2243],
#  [165,
#   493,
#   101,
#   158,
#   4407,
#   48,
#   692,
#   2357,
#   10,
#   5,
#   468,
#   1335,
#   155,
#   273,
#   3,
#   4408,
#   1668,
#   4409,
#   48,
#   4410,
#   1336],
#  [4411, 106, 2, 225],
#  [893, 358, 692, 480, 807, 72, 4412],
#  [925, 39, 318],
#  [2115,
#   2150,
#   6,
#   29,
#   4413,
#   848,
#   3,
#   1314,
#   99,
#   15,
#   1,
#   18,
#   5,
#   532,
#   6,
#   5,
#   533,
#   1696,
#   2,
#   265,
#   13,
#   465],
#  [1, 62, 66, 577, 56, 2358, 6, 1, 63, 80, 1, 58, 25, 430, 19, 31, 37],
#  [106, 17, 79, 304, 72, 206, 197, 5, 333, 72, 32, 90],
#  [4414,
#   111,
#   107,
#   139,
#   7,
#   319,
#   13,
#   42,
#   1,
#   40,
#   7,
#   42,
#   4,
#   285,
#   874,
#   477,
#   7,
#   381,
#   13,
#   86],
#  [8, 1993],
#  [1, 141, 922, 28, 217, 1, 63, 76, 2, 4415, 623, 534, 78, 334, 1337, 338, 423],
#  [1,
#   137,
#   168,
#   374,
#   1338,
#   2359,
#   20,
#   1,
#   903,
#   1697,
#   1339,
#   2234,
#   19,
#   1678,
#   2120,
#   55],
#  [4416, 4417, 1524, 109, 650, 4418, 4419, 668, 4420],
#  [984,
#   4421,
#   31,
#   61,
#   2360,
#   8,
#   4422,
#   675,
#   133,
#   2361,
#   3,
#   2362,
#   1200,
#   26,
#   231,
#   95,
#   2363,
#   167,
#   535,
#   99,
#   228,
#   4423,
#   1,
#   248,
#   23,
#   35,
#   1698,
#   286],
#  [4424, 658, 1, 121, 1, 183, 18, 392, 43, 93, 487],
#  [107, 8, 242, 53, 2, 108, 1, 411, 28, 19, 1973, 37, 856],
#  [5, 1699, 46, 500, 596, 3, 1276, 82, 1, 22, 2364, 9, 1, 497, 328, 29],
#  [1,
#   38,
#   91,
#   5,
#   567,
#   481,
#   13,
#   151,
#   9,
#   22,
#   2,
#   440,
#   1,
#   183,
#   18,
#   392,
#   2,
#   3,
#   1340,
#   37],
#  [4425,
#   3,
#   812,
#   65,
#   8,
#   116,
#   200,
#   7,
#   48,
#   4426,
#   163,
#   30,
#   47,
#   43,
#   113,
#   7,
#   57,
#   2,
#   850],
#  [67, 108, 15, 17, 109, 2365, 19, 197, 4, 436, 1, 59, 47, 115],
#  [113, 27],
#  [26,
#   4427,
#   202,
#   8,
#   144,
#   186,
#   159,
#   1,
#   355,
#   1125,
#   2366,
#   20,
#   466,
#   9,
#   66,
#   694,
#   2,
#   13,
#   766,
#   4428,
#   694,
#   45,
#   184],
#  [36, 114, 50, 4429, 320, 26, 14, 5, 617, 518, 1246, 13, 33],
#  [144,
#   4,
#   146,
#   201,
#   12,
#   2367,
#   95,
#   1337,
#   3,
#   479,
#   1,
#   45,
#   23,
#   488,
#   52,
#   5,
#   4430,
#   1,
#   75,
#   120,
#   2367],
#  [4431,
#   4432,
#   127,
#   274,
#   398,
#   3,
#   943,
#   184,
#   1,
#   1056,
#   1,
#   139,
#   342,
#   9,
#   159,
#   73,
#   4433,
#   60,
#   4,
#   629,
#   477,
#   35,
#   985,
#   14,
#   71,
#   487],
#  [34, 207, 2057, 577, 293, 16, 8, 4434, 2, 2368],
#  [1,
#   62,
#   1700,
#   73,
#   239,
#   21,
#   612,
#   510,
#   2,
#   1701,
#   9,
#   437,
#   9,
#   210,
#   824,
#   496,
#   289,
#   43,
#   986,
#   6,
#   2369,
#   2370,
#   3,
#   220],
#  [21,
#   52,
#   56,
#   4,
#   4435,
#   791,
#   2,
#   3,
#   1575,
#   4436,
#   223,
#   291,
#   5,
#   1341,
#   2371,
#   604,
#   4437,
#   29],
#  [4438, 4439, 54, 39, 7, 164, 151, 573, 23, 4440, 6, 95, 105],
#  [4441, 44, 26, 1599, 202, 8, 673],
#  [127, 1342, 578, 477, 75, 157, 471, 27, 20, 875, 14, 2372, 27],
#  [4442,
#   35,
#   48,
#   61,
#   144,
#   1257,
#   123,
#   24,
#   241,
#   65,
#   78,
#   61,
#   4443,
#   11,
#   212,
#   1036,
#   1685,
#   4444,
#   20,
#   78,
#   1,
#   1664,
#   7,
#   59],
#  [4445,
#   620,
#   87,
#   23,
#   7,
#   1255,
#   74,
#   102,
#   4,
#   295,
#   1,
#   137,
#   59,
#   7,
#   400,
#   188,
#   1343,
#   12,
#   3,
#   2373,
#   6,
#   4446,
#   1,
#   222],
#  [4447, 1, 143, 32, 41, 458, 147, 945, 447, 147, 945, 447],
#  [8,
#   1532,
#   91,
#   747,
#   4448,
#   256,
#   603,
#   6,
#   91,
#   825,
#   4449,
#   8,
#   15,
#   580,
#   24,
#   4450,
#   11,
#   4451,
#   6,
#   1702,
#   2,
#   223,
#   1344],
#  [2374,
#   1,
#   1703,
#   9,
#   4452,
#   82,
#   83,
#   2011,
#   122,
#   405,
#   541,
#   797,
#   33,
#   2,
#   186,
#   1,
#   397,
#   160,
#   308,
#   2,
#   178,
#   20,
#   1,
#   71,
#   40,
#   178],
#  [4453, 2, 241, 4, 357, 10, 1345, 12, 3, 4454, 1, 63, 273, 29, 1, 117, 4455],
#  [4456, 267, 1, 22, 766, 2, 18, 4, 30, 210, 4457],
#  [4458,
#   15,
#   251,
#   78,
#   62,
#   1,
#   53,
#   2,
#   77,
#   7,
#   1,
#   75,
#   7,
#   38,
#   380,
#   6,
#   17,
#   241,
#   987,
#   4459],
#  [4460,
#   311,
#   2375,
#   4461,
#   375,
#   25,
#   112,
#   161,
#   25,
#   4462,
#   4463,
#   10,
#   3,
#   776,
#   4464,
#   2376,
#   6,
#   4465],
#  [1, 63, 76, 5, 180, 2, 374],
#  [431,
#   5,
#   499,
#   143,
#   771,
#   583,
#   79,
#   2,
#   1704,
#   4466,
#   176,
#   4467,
#   17,
#   235,
#   1296,
#   58,
#   25,
#   2377],
#  [772, 9, 4468, 1, 32, 4469, 290, 187, 440, 86, 15, 115, 371, 19, 406, 111],
#  [470, 1269, 29, 134, 418, 900],
#  [4470,
#   61,
#   21,
#   676,
#   83,
#   47,
#   26,
#   200,
#   10,
#   276,
#   1,
#   670,
#   91,
#   200,
#   9,
#   58,
#   25,
#   10,
#   1705,
#   6,
#   47,
#   122,
#   25,
#   4471,
#   10,
#   1705],
#  [2378,
#   4472,
#   45,
#   103,
#   21,
#   102,
#   4473,
#   4474,
#   4475,
#   2379,
#   6,
#   1,
#   75,
#   3,
#   205,
#   6,
#   1,
#   62,
#   1257,
#   237],
#  [4476,
#   1126,
#   1,
#   4477,
#   7,
#   4,
#   739,
#   249,
#   4478,
#   83,
#   15,
#   1527,
#   16,
#   14,
#   1658,
#   6,
#   3,
#   4479,
#   711,
#   297,
#   2303,
#   2380,
#   2381],
#  [67, 209, 20, 342, 737, 23, 2382, 6, 4480, 851, 142, 136, 17, 4481, 2, 2382],
#  [4482, 43, 4483],
#  [4484, 5, 271, 4485, 20, 3, 2383, 317, 104, 363, 375, 1706, 10, 3, 4486],
#  [4487, 18, 7, 428, 9, 47, 1058],
#  [4488, 2384, 2384, 13, 6, 41, 567, 64, 850, 6, 1, 429, 77, 1346, 286],
#  [4489, 366, 5, 567, 4, 394, 477, 369],
#  [988, 164, 5, 606, 504, 491],
#  [5,
#   2385,
#   4490,
#   8,
#   31,
#   1707,
#   6,
#   24,
#   3,
#   30,
#   313,
#   12,
#   1707,
#   3,
#   66,
#   1127,
#   313,
#   12,
#   1707,
#   161,
#   18,
#   2,
#   4491,
#   9,
#   292],
#  [4492, 171, 4493, 222, 54, 1, 18, 4494, 312, 17, 53, 75, 7, 2386, 171],
#  [2387,
#   2388,
#   9,
#   10,
#   55,
#   1,
#   686,
#   83,
#   7,
#   49,
#   1510,
#   9,
#   2,
#   194,
#   446,
#   1,
#   21,
#   230,
#   1,
#   128,
#   215,
#   7,
#   59,
#   5,
#   4495],
#  [1, 265, 599, 4496, 82, 4497, 194, 128, 488, 13, 2389],
#  [4498, 69, 208, 17, 66, 106, 1, 118, 7, 57, 4, 1065, 12, 30, 578, 19, 227],
#  [104,
#   438,
#   27,
#   43,
#   113,
#   1,
#   18,
#   2,
#   405,
#   28,
#   26,
#   4499,
#   15,
#   15,
#   184,
#   6,
#   1,
#   397,
#   38,
#   37],
#  [577, 678, 63, 117, 30, 1, 118, 9, 258, 2307, 9, 11, 589],
#  [989, 35, 7, 8, 24, 442],
#  [61,
#   162,
#   450,
#   13,
#   1708,
#   1709,
#   1,
#   117,
#   4500,
#   61,
#   14,
#   493,
#   88,
#   4,
#   2390,
#   174,
#   76,
#   5,
#   797],
#  [443, 407, 121, 1, 22, 19, 4501],
#  [279, 27, 11, 13, 36, 990, 13, 4502],
#  [713, 92, 298, 991, 132, 284, 554, 133, 17, 66, 53, 2, 75, 92],
#  [399, 163, 19, 16, 310],
#  [4503,
#   20,
#   1,
#   85,
#   60,
#   224,
#   1710,
#   1711,
#   6,
#   17,
#   4504,
#   207,
#   69,
#   91,
#   1,
#   876,
#   512,
#   512,
#   512],
#  [47, 2391, 43, 217, 2, 25, 602, 126, 356],
#  [5, 561, 103, 102, 555, 508, 982, 84, 36, 404, 50, 4505],
#  [182,
#   32,
#   2392,
#   2378,
#   182,
#   137,
#   1105,
#   91,
#   61,
#   144,
#   2,
#   84,
#   1128,
#   19,
#   568,
#   124,
#   29,
#   721,
#   29,
#   83,
#   1214,
#   64,
#   4506,
#   4,
#   4507,
#   215,
#   13,
#   59],
#  [933, 4508, 958, 22, 4, 454, 36, 404, 50, 4509],
#  [14,
#   212,
#   593,
#   1712,
#   58,
#   1461,
#   4510,
#   2393,
#   12,
#   4511,
#   4512,
#   123,
#   28,
#   2,
#   349,
#   659,
#   4513,
#   96,
#   2394,
#   1228,
#   301,
#   36,
#   4514,
#   61,
#   1712,
#   1347],
#  [4515, 35, 61, 10, 3, 4516, 150, 29, 96, 1578, 33, 150, 78, 68, 46, 88],
#  [4517, 17, 150, 88, 23, 7, 47, 15, 279, 2, 2395, 23, 3, 2396, 1348, 291],
#  [1, 62, 24, 4, 4518, 62, 1],
#  [4519, 266, 420, 2397, 11, 13, 2397, 11, 5, 243],
#  [339, 339, 339, 915, 1637],
#  [4520,
#   145,
#   102,
#   226,
#   44,
#   29,
#   1,
#   18,
#   2227,
#   26,
#   8,
#   1694,
#   94,
#   11,
#   3,
#   1349,
#   1350],
#  [4521, 1, 76, 2, 34, 20, 47, 1325, 27, 14, 322],
#  [4522, 75, 7, 4523],
#  [270,
#   27,
#   19,
#   568,
#   37,
#   6,
#   5,
#   270,
#   58,
#   25,
#   19,
#   79,
#   4524,
#   71,
#   4525,
#   56,
#   92,
#   1277],
#  [17,
#   24,
#   14,
#   109,
#   340,
#   11,
#   5,
#   2398,
#   2,
#   281,
#   25,
#   4526,
#   14,
#   4,
#   1129,
#   877,
#   72,
#   1684,
#   648,
#   7,
#   64,
#   384,
#   212,
#   78,
#   7,
#   182,
#   219,
#   3,
#   223],
#  [539,
#   54,
#   60,
#   2399,
#   71,
#   956,
#   186,
#   216,
#   4527,
#   123,
#   7,
#   47,
#   4528,
#   24,
#   4,
#   30,
#   216],
#  [4529, 1130, 6, 1, 668, 4530, 2, 342, 2400, 48, 1027, 35, 100],
#  [222, 174, 21, 1131, 224, 757, 12, 4531, 366, 26, 1538, 4532, 150, 90],
#  [4533, 17, 106, 2, 225, 9, 7, 63, 1609, 16],
#  [126, 1325, 27, 1351, 121, 1, 22, 79, 23, 5, 270, 101, 40, 64, 547, 41, 403],
#  [4534,
#   772,
#   9,
#   22,
#   4,
#   1713,
#   2401,
#   1081,
#   51,
#   1036,
#   1714,
#   224,
#   1715,
#   1132,
#   266,
#   4535,
#   44],
#  [17, 2186, 123, 3, 1240, 12, 2402],
#  [142,
#   295,
#   1,
#   4536,
#   157,
#   346,
#   31,
#   1,
#   80,
#   60,
#   171,
#   2403,
#   393,
#   2404,
#   1118,
#   171,
#   1,
#   1716,
#   61,
#   10,
#   1717,
#   4537,
#   90,
#   20,
#   3,
#   4538,
#   1282,
#   13,
#   870],
#  [1, 255, 5, 702],
#  [4539, 412, 23, 92, 270, 306, 387, 95, 15, 132, 67, 138, 9],
#  [21, 46, 52, 56, 3, 1061, 1, 46, 852, 14, 5, 1305, 70, 577],
#  [4540, 558, 5, 2405, 4541, 1, 420, 341, 137, 117, 30, 85, 108],
#  [91,
#   148,
#   18,
#   1,
#   24,
#   102,
#   1352,
#   14,
#   5,
#   1353,
#   6,
#   4542,
#   1,
#   143,
#   1105,
#   1,
#   22,
#   4543,
#   33],
#  [4544,
#   109,
#   1285,
#   144,
#   31,
#   3,
#   4545,
#   288,
#   6,
#   68,
#   39,
#   858,
#   2,
#   342,
#   6,
#   111,
#   371,
#   11,
#   231,
#   1264,
#   24,
#   120,
#   19,
#   31],
#  [4546,
#   4547,
#   2406,
#   1,
#   2407,
#   2,
#   699,
#   11,
#   4548,
#   4549,
#   4550,
#   197,
#   53,
#   33,
#   4551,
#   39,
#   120,
#   20,
#   24,
#   72,
#   25,
#   4552],
#  [1, 75, 4553],
#  [4554, 1, 63, 18, 4555],
#  [16,
#   22,
#   69,
#   43,
#   1133,
#   54,
#   3,
#   1561,
#   48,
#   47,
#   220,
#   27,
#   1,
#   63,
#   168,
#   25,
#   10,
#   1524,
#   17,
#   144,
#   33,
#   44],
#  [4556, 554, 26, 1274, 8, 4557, 13, 15, 93],
#  [47, 944, 17, 53, 2, 18, 81, 4558, 231, 4559, 305, 1718, 13],
#  [4560,
#   7,
#   63,
#   168,
#   59,
#   60,
#   3,
#   1495,
#   15,
#   1,
#   67,
#   2240,
#   2,
#   7,
#   54,
#   4561,
#   8,
#   7,
#   195,
#   686],
#  [4562,
#   109,
#   258,
#   45,
#   70,
#   14,
#   5,
#   800,
#   1,
#   67,
#   898,
#   7,
#   1,
#   4563,
#   4564,
#   441,
#   8,
#   4565,
#   48,
#   2408,
#   256,
#   2409,
#   286],
#  [4566,
#   17,
#   106,
#   5,
#   4567,
#   8,
#   16,
#   116,
#   60,
#   228,
#   271,
#   125,
#   22,
#   31,
#   11,
#   4,
#   4568,
#   306,
#   125,
#   4569,
#   1050,
#   3,
#   4570,
#   140,
#   25,
#   392],
#  [1719, 466, 3, 156, 19, 4571, 39, 2410],
#  [5, 243, 430, 2, 1327, 8, 2411, 43, 344],
#  [1, 62, 383, 4572, 6, 5, 6, 4573, 21, 4574, 224, 916, 2026],
#  [373,
#   70,
#   9,
#   66,
#   258,
#   163,
#   38,
#   2412,
#   32,
#   35,
#   108,
#   1955,
#   4575,
#   21,
#   2413,
#   13,
#   100,
#   1720,
#   55,
#   94,
#   2414],
#  [743, 125, 22, 19, 3, 4576],
#  [4577,
#   6,
#   4578,
#   22,
#   279,
#   2,
#   1026,
#   143,
#   2415,
#   13,
#   4579,
#   26,
#   89,
#   15,
#   58,
#   18,
#   2,
#   4580,
#   3,
#   1026,
#   2,
#   4,
#   701,
#   301,
#   105],
#  [18,
#   102,
#   134,
#   275,
#   917,
#   14,
#   4581,
#   2416,
#   105,
#   48,
#   2417,
#   57,
#   4582,
#   15,
#   230,
#   1,
#   57,
#   9,
#   10,
#   3,
#   1721,
#   2418,
#   3,
#   4583,
#   2419,
#   103,
#   2409],
#  [4584, 130, 112, 20, 32, 16, 728, 207, 56, 9],
#  [16, 548, 95, 269, 19, 3, 407, 1722, 10, 2, 4, 113, 852, 536],
#  [4585,
#   366,
#   1,
#   4586,
#   18,
#   2,
#   34,
#   461,
#   2080,
#   1723,
#   2420,
#   31,
#   27,
#   6,
#   2421,
#   272,
#   291],
#  [4587,
#   447,
#   447,
#   4588,
#   1049,
#   878,
#   4589,
#   20,
#   9,
#   137,
#   45,
#   43,
#   93,
#   410,
#   26,
#   8,
#   814,
#   6,
#   24,
#   878,
#   4590],
#  [4591, 486, 54, 313, 12, 4592, 8, 125, 164],
#  [161, 25, 79, 4593, 239, 4594, 15, 115],
#  [4595,
#   3,
#   4596,
#   1,
#   22,
#   766,
#   2,
#   557,
#   102,
#   226,
#   2,
#   647,
#   157,
#   3,
#   98,
#   97,
#   350,
#   145,
#   102,
#   90,
#   57,
#   2,
#   1046,
#   33,
#   12,
#   173,
#   1134],
#  [24, 4597, 151, 31, 536, 1, 85, 4, 395],
#  [121, 1, 22, 19, 405, 9, 4, 449, 124],
#  [99, 2, 3, 1135, 1, 62, 66, 4598, 268, 2, 34],
#  [5, 2422, 1589, 558, 5, 52, 37, 99, 2, 1502, 292, 11, 4599, 4600],
#  [4601, 132, 46, 4, 55, 33, 442, 860, 67, 848, 28],
#  [216, 201, 288, 11, 3, 205],
#  [1724,
#   1,
#   76,
#   2,
#   34,
#   2,
#   108,
#   189,
#   2423,
#   13,
#   204,
#   1354,
#   4602,
#   6,
#   29,
#   4,
#   2424,
#   26,
#   522,
#   25,
#   1615,
#   218,
#   1225],
#  [4603, 311, 1, 21, 80, 194, 128, 545, 13, 189, 90, 10, 4604, 2, 1725, 13, 28],
#  [14, 1726, 11, 3, 98, 55, 979, 28, 5, 1355, 6, 4605],
#  [4606,
#   353,
#   457,
#   290,
#   45,
#   513,
#   2425,
#   217,
#   1,
#   62,
#   4,
#   1975,
#   1,
#   183,
#   18,
#   396,
#   16,
#   108,
#   43],
#  [4607, 417, 113, 468, 14, 555, 33, 14, 3, 220, 3, 560, 143, 45, 171],
#  [4608, 13, 43],
#  [69,
#   3,
#   4609,
#   89,
#   4610,
#   1655,
#   14,
#   452,
#   5,
#   4611,
#   616,
#   8,
#   414,
#   4,
#   1727,
#   6,
#   4,
#   4612],
#  [21,
#   57,
#   73,
#   614,
#   902,
#   2274,
#   4613,
#   48,
#   569,
#   1728,
#   1549,
#   112,
#   1,
#   76,
#   100,
#   36,
#   114,
#   50,
#   4614],
#  [493,
#   83,
#   154,
#   33,
#   88,
#   301,
#   111,
#   225,
#   26,
#   154,
#   1487,
#   107,
#   7,
#   274,
#   25,
#   15,
#   1487,
#   1136,
#   493],
#  [194,
#   57,
#   21,
#   1091,
#   131,
#   4,
#   1595,
#   10,
#   5,
#   1643,
#   239,
#   538,
#   2,
#   209,
#   9,
#   20,
#   8,
#   596,
#   4,
#   252,
#   81,
#   10,
#   344,
#   113,
#   2426,
#   470,
#   4615,
#   368],
#  [2427, 4616, 1356, 8, 1602, 13, 4617, 2427, 4618],
#  [197, 62, 457, 116, 43, 747],
#  [103,
#   4619,
#   23,
#   4620,
#   2428,
#   2,
#   32,
#   81,
#   4621,
#   1053,
#   20,
#   96,
#   362,
#   609,
#   4622,
#   286,
#   1729,
#   12,
#   3,
#   4623,
#   25,
#   4624,
#   54,
#   7,
#   248],
#  [244, 442, 4625, 2318, 740, 1730, 13, 56, 2429],
#  [318,
#   2,
#   1627,
#   23,
#   3,
#   708,
#   16,
#   101,
#   4626,
#   4627,
#   119,
#   2,
#   4628,
#   4629,
#   4630,
#   4631,
#   31,
#   231,
#   148],
#  [4632, 16, 8, 279, 1, 62, 24, 721, 21, 4633, 33],
#  [9, 22, 4, 1683, 4, 1310, 84],
#  [934, 1, 121, 1, 57, 3, 2430, 11, 4, 344, 759, 6, 24, 4, 4634],
#  [4635,
#   312,
#   129,
#   2431,
#   17,
#   879,
#   10,
#   175,
#   226,
#   2,
#   108,
#   20,
#   1,
#   67,
#   448,
#   2,
#   13,
#   2,
#   265,
#   13,
#   4636,
#   237,
#   61,
#   4637],
#  [5, 837, 360, 6, 17, 304],
#  [69, 2432, 100, 380, 2433, 4638, 14, 2173],
#  [4639, 168, 5, 702, 2, 25, 52],
#  [12, 14, 3, 4640, 216, 201, 29],
#  [1066, 23, 503],
#  [4641,
#   149,
#   4642,
#   992,
#   147,
#   97,
#   1731,
#   15,
#   93,
#   43,
#   7,
#   59,
#   4643,
#   628,
#   628,
#   379,
#   4644,
#   1732,
#   4645,
#   4646,
#   688,
#   4647,
#   11,
#   3,
#   414,
#   12,
#   186,
#   147,
#   97],
#  [4648, 1, 67, 32, 16, 4649, 853, 16, 51, 139, 11, 13, 2, 45],
#  [4650,
#   16,
#   4651,
#   4652,
#   6,
#   2434,
#   4653,
#   52,
#   2,
#   52,
#   63,
#   880,
#   43,
#   70,
#   69,
#   70,
#   19,
#   227,
#   132,
#   71,
#   457,
#   10,
#   1733,
#   10,
#   4654],
#  [490, 1357, 10, 4655, 630, 1686, 38, 26, 394, 24, 2435, 66, 181, 239],
#  [1, 80, 156, 32, 33, 12, 175, 10, 3, 4656, 676, 91, 96, 64, 1734, 13, 99],
#  [653,
#   68,
#   85,
#   653,
#   4657,
#   630,
#   653,
#   115,
#   31,
#   3,
#   636,
#   4658,
#   3,
#   653,
#   4659,
#   218,
#   4660,
#   129,
#   24,
#   150,
#   47,
#   92,
#   711,
#   43],
#  [8, 130, 282, 11, 105, 286, 15, 115, 19, 3, 1526, 234, 55],
#  [467, 211, 52, 19, 45, 8, 35, 120, 36, 563, 50, 266, 4661],
#  [21,
#   993,
#   23,
#   763,
#   4662,
#   11,
#   1735,
#   47,
#   21,
#   43,
#   4663,
#   159,
#   11,
#   13,
#   1,
#   63,
#   38,
#   4664,
#   382],
#  [15,
#   1736,
#   2436,
#   33,
#   63,
#   215,
#   806,
#   32,
#   851,
#   12,
#   41,
#   293,
#   466,
#   7,
#   219,
#   74,
#   133,
#   814,
#   48,
#   1322,
#   147,
#   97],
#  [1,
#   66,
#   182,
#   2437,
#   224,
#   152,
#   19,
#   179,
#   15,
#   93,
#   491,
#   2,
#   25,
#   162,
#   182,
#   1,
#   21,
#   166,
#   4,
#   27,
#   374,
#   95,
#   2290],
#  [4665,
#   4666,
#   4667,
#   4668,
#   4669,
#   1358,
#   65,
#   27,
#   68,
#   335,
#   1737,
#   4670,
#   69,
#   445,
#   4671,
#   1,
#   182,
#   34,
#   4672,
#   46,
#   45,
#   10,
#   3,
#   867],
#  [4673, 1322, 1296, 2438, 13, 12, 4674],
#  [4675, 2439, 2, 2440, 1738, 293, 10, 1739, 470, 51],
#  [145,
#   57,
#   2,
#   4676,
#   31,
#   5,
#   4677,
#   33,
#   26,
#   205,
#   1242,
#   2,
#   5,
#   1060,
#   52,
#   167,
#   57,
#   9,
#   26,
#   113,
#   218,
#   144,
#   214,
#   55,
#   11,
#   1740,
#   2422],
#  [180,
#   1237,
#   2,
#   881,
#   3,
#   1629,
#   17,
#   24,
#   216,
#   70,
#   141,
#   2,
#   75,
#   31,
#   3,
#   120,
#   6,
#   1629],
#  [71, 24, 46, 4, 87, 4678, 2441, 65, 8, 24, 4679],
#  [4680, 18, 263, 3, 1741, 16, 648, 35, 100, 1312, 24, 142, 660, 134, 29, 420],
#  [4681,
#   1,
#   4682,
#   76,
#   2,
#   20,
#   18,
#   51,
#   391,
#   757,
#   3,
#   4683,
#   14,
#   4684,
#   2067,
#   15,
#   5,
#   615,
#   137,
#   76,
#   13,
#   2,
#   34,
#   88,
#   4685],
#  [1359, 43, 315, 2, 32, 1137],
#  ...]

# %%
print(encoded_text[:30])
# Out:
# [[8, 304, 6, 345, 2, 191, 4, 236, 254, 3079], [52, 10, 1019, 206, 2, 3080, 3081], [3082, 1197, 668, 1955, 3083, 1956, 3084, 1, 3085, 17, 115, 44], [1957, 1, 62, 15, 192, 3086], [3087, 13, 113, 47, 328, 136, 3088, 3089, 8, 101, 88, 11, 4, 285, 136, 48, 2, 448, 21, 277, 3, 3090, 218, 3, 449], [3091, 17, 15, 315, 19, 3, 892, 164, 5, 1459, 14, 3092, 3093, 386, 8, 66, 1460], [3094, 110, 366, 20, 1, 66, 85, 2, 108, 1, 117, 38, 536, 44, 182, 108, 78, 346, 207, 305, 17, 3095], [450, 73, 537, 569, 295, 1, 316, 2, 77, 3096, 367, 3097, 1461, 24, 187, 893], [3098, 21, 1958, 304, 19, 45, 44], [409, 3099, 3100], [3101, 132, 609, 79, 3, 193, 368, 17, 131, 3, 158, 199], [3102, 127, 1, 139, 226, 2, 1020, 9, 29, 1, 222, 74, 55, 2, 3103, 16, 3104], [67, 894, 423], [1959, 119, 52, 56, 211, 159, 387, 669, 48, 68, 255, 1462, 3, 3105, 71, 570, 5, 1959, 329], [1960, 3106, 3107, 46, 3108, 3109], [3110, 1463, 70, 19, 227, 17, 28, 2], [3111, 1, 245, 212, 1961, 51, 72, 36, 146, 246, 3112, 1, 538, 20, 74, 507, 1962, 410, 1, 1198, 219, 787], [3113, 69, 1, 1021, 5, 3114, 33, 2, 1199, 451, 263, 12, 9, 388, 1, 143, 76, 2, 316, 1464, 73, 159, 1465], [3115, 3116, 31, 12, 39, 3117, 9, 20, 96, 39, 24, 1466, 3118, 1200, 386, 507, 369, 15, 68, 571, 32, 2, 1022, 2, 51], [3119, 165, 88, 35, 64, 49, 1963, 6, 24, 52, 10, 572, 306, 1467, 176, 152, 75, 7], [3120, 15, 788, 78, 9, 610, 95, 91, 20, 1, 3121, 789, 370, 7, 91, 39, 7, 91, 18, 7, 102], [54, 8, 28, 23, 5, 3122], [52, 3123, 86, 37, 611, 15, 473, 452, 82, 1201, 101, 719, 153, 1468, 790, 11, 188, 3124], [3125, 69, 1, 670, 83, 3, 1964, 14, 3, 1469, 8, 720, 2, 34], [3126, 7, 347, 42, 3127, 11, 573, 42, 1, 22, 1965, 1966], [3128, 87, 671, 8, 101, 3129, 153, 207, 256, 16, 8, 1023], [1470, 3, 3130, 38, 35, 223], [539, 1, 18, 4, 389, 10, 5, 1967, 43], [1, 612, 2, 18, 255, 5, 1024, 1471], [52, 56, 3, 424, 3131, 102, 4, 148, 55, 508, 1, 98, 57, 3132, 3133, 3134, 3135, 227, 3136, 8, 14, 92, 116, 2, 791, 13]]

# %% [markdown]
# We can see that the length of each tweet is different. The length of all encoded tweets must be same before feeding them to the neural network. Hence we are using pad_sequences which pads zeros to reviews with length less than 120.

# %%
max_length = 120
X = pad_sequences(encoded_text, maxlen=max_length, padding='post')
print(X)
# Out:
# [[    8   304     6 ...     0     0     0]
#  [   52    10  1019 ...     0     0     0]
#  [ 3082  1197   668 ...     0     0     0]
#  ...
#  [ 1033    21  1021 ...     0     0     0]
#  [10134   134     7 ...     0     0     0]
#  [   94    11   226 ...     0     0     0]]

# %%
X.shape
# Out:
# (4000, 120)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.2, stratify = y)

# %% [markdown]
# GlobalMaxPooling1D() downsamples the input representation by taking the maximum value over the time dimension.

# %%
vec_size = 300

model = Sequential()
model.add(Embedding(vocab_size, vec_size, input_length=max_length))

model.add(Conv1D(64, 8, activation = 'relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(16, activation='relu'))

model.add(GlobalMaxPooling1D())

model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# %%time
model.fit(X_train, y_train, epochs = 5, validation_data = (X_test, y_test))
# Out:
# Epoch 1/5
# 100/100 [==============================] - 15s 143ms/step - loss: 0.6952 - accuracy: 0.4863 - val_loss: 0.6929 - val_accuracy: 0.5150
# Epoch 2/5
# 100/100 [==============================] - 14s 140ms/step - loss: 0.6890 - accuracy: 0.5275 - val_loss: 0.6552 - val_accuracy: 0.6575
# Epoch 3/5
# 100/100 [==============================] - 14s 139ms/step - loss: 0.5641 - accuracy: 0.7216 - val_loss: 0.5536 - val_accuracy: 0.7425
# Epoch 4/5
# 100/100 [==============================] - 14s 140ms/step - loss: 0.2831 - accuracy: 0.8981 - val_loss: 0.5930 - val_accuracy: 0.7100
# Epoch 5/5
# 100/100 [==============================] - 14s 140ms/step - loss: 0.1119 - accuracy: 0.9616 - val_loss: 0.6952 - val_accuracy: 0.7163
# CPU times: user 2min 5s, sys: 3.28 s, total: 2min 8s
# Wall time: 1min 22s

# %%
def get_encoded(x):
    x = token.texts_to_sequences(x)
    x = pad_sequences(x, maxlen=max_length, padding = 'post')
    return x

x = ['worst services. will not come again']
model.predict_classes(get_encoded(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([[0]], dtype=int32)

# %%
x = ['thank you for watching']
model.predict_classes(get_encoded(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([[1]], dtype=int32)
