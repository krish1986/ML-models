# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle #copy the file to the directory created above

# %%
# !chmod 600 ~/.kaggle/kaggle.json #change permission on this json file

# %%
# !kaggle competitions download -c dogs-vs-cats #copy API command from kaggle data
# Out:
# ...
#  97% 262M/271M [00:03<00:00, 128MB/s]
# 100% 271M/271M [00:03<00:00, 90.1MB/s]
# ...
#   0% 0.00/86.8k [00:00<?, ?B/s]
# 100% 86.8k/86.8k [00:00<00:00, 85.1MB/s]
# ...
# 100% 543M/543M [00:03<00:00, 185MB/s]
# 100% 543M/543M [00:03<00:00, 164MB/s]

# %%
# !kaggle datasets list #some list of datasets available in kaggle
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              234KB  2021-07-20 07:51:04           9529
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           5796
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           2137
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-07-03 18:37:20           2453
# ...
